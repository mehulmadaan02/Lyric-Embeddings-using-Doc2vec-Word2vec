# %% [markdown]
# # Lyrics based Word Embeddings using Doc2vec & Word2Vec on MusicXmatch Dataset

# %% [markdown]
# ### Importing all the Data Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
from collections import Counter
import os    
import re

# %% [markdown]
# ### Importing NLP Libraries

# %%
import nltk

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/mehulmadaan/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/mehulmadaan/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from nltk.corpus import stopwords
print(set(stopwords.words('english')))
# Out:
# {'very', 'most', 'o', "you've", 'them', 'itself', 'mustn', 'd', 'such', 're', 'ain', 'our', 'before', 'yourselves', 't', 'to', 'we', 'should', "it's", 'whom', 'i', "wouldn't", 'mightn', 'aren', "haven't", 'doesn', 'again', 'about', 'can', 'll', 'all', 'she', 'but', 'they', 'weren', 'he', 'wasn', "needn't", 'those', 'against', 'out', 'shouldn', "weren't", 'myself', 'too', 'wouldn', "she's", 'him', 'you', 'hadn', 'few', 'hers', 'yours', 'a', 'above', 'y', 'ours', 'from', 'himself', 'further', 'until', 'just', 'being', 'of', "won't", 'have', "you're", 'down', 'between', 'only', 'this', 'couldn', 'both', 've', 'their', 'after', 'not', 'didn', 'isn', 'below', "didn't", 'these', 'has', 'his', 'up', 'her', 'it', 'what', 'was', 'under', 'haven', 'me', "shouldn't", 'been', 'herself', 'will', 'more', 'there', "you'll", 'in', 'hasn', 'some', 'does', 'nor', "couldn't", 'if', 'who', 'having', 'your', 'here', "doesn't", 'that', "mightn't", 'needn', 'other', 'on', 'off', 'now', "aren't", 'into', "should've", 'than', 'theirs', 'then', 'don', 'an', "you'd", 'had', 'its', 'through', 'ma', 'themselves', 'shan', "shan't", 'doing', 'why', 'when', "don't", 'where', "hasn't", 'for', 'ourselves', 'the', 'by', 'so', 'same', "that'll", 'any', 'over', 'how', "mustn't", 'yourself', 'while', "hadn't", 'with', "isn't", 'won', 'which', 'and', 'or', 'during', 'because', 'each', 'my', 's', 'are', 'own', 'no', 'am', 'once', 'did', 'be', 'as', 'do', "wasn't", 'were', 'is', 'at', 'm'}

# %%
remove=set(stopwords.words('english'))
REMOVE_STOPWORDS = True

# %%
from nltk.tokenize import word_tokenize

# %% [markdown]
# ### Reading Data from file

# %%
#Opening file in Reading mode
with open('/Users/mehulmadaan/Downloads/ProjectDoc2vec/mxm_dataset_train.txt','r') as data:
    lines=data.readlines()  #Reading data line by line
    words = lines[17].replace('%','').split(',')   #The first 17 lines of the dataset are usage info
    all_songs_dict = dict()
    for i,l in list(enumerate(lines))[18:]:        #Adding a counter to the iterable words
        song_info = l.split(',')
        MSDID = song_info[0]                       
        song_bow = [x.split(':') for x in song_info[2:]]
        song_dict = {}
        for word, word_count in song_bow:
            song_dict[int(word)] = int(word_count.replace('\n',''))
        word_lists = [[words[word-1]]*song_dict[word] for word in song_dict.keys()]
        song = [word for word_list in word_lists for word in word_list]
        if REMOVE_STOPWORDS:
            song = [w for w in song if w not in remove]
        all_songs_dict[str(MSDID)] = ' '.join(song).replace('\n','')

# %% [markdown]
# #### Over Here,
# #### 'TRZZZYX128F92D32C6' is the Track ID
# #### ' 681124' is the Track ID from MusicXmatch Dataset
# ##### '1:4', where 1 is the Word Index and 4 is the Word count

# %%
l
# Out:
# 'TRZZZYX128F92D32C6,681124,1:4,2:18,4:3,5:6,6:9,7:1,8:5,9:1,10:12,11:2,12:9,13:5,15:4,17:2,18:4,19:4,21:2,22:3,25:3,29:2,30:3,32:5,34:3,35:2,37:2,39:3,43:2,44:7,45:2,49:2,50:2,52:8,54:2,56:1,59:1,63:10,64:1,66:1,71:2,72:1,78:1,79:1,84:2,91:1,92:2,95:1,96:1,103:1,110:1,115:1,127:1,134:4,135:2,136:3,137:1,138:2,140:1,146:2,150:1,152:1,192:1,206:1,207:1,222:3,239:1,248:2,258:1,270:1,274:1,283:1,294:2,300:1,305:1,318:1,337:1,338:1,346:1,347:1,349:1,371:1,398:1,406:1,445:1,451:1,459:1,478:1,487:1,492:1,502:3,516:1,539:1,548:2,549:1,553:1,592:2,617:1,633:1,666:1,681:1,727:1,774:1,775:7,789:1,811:1,844:1,915:1,942:1,950:1,979:1,1008:1,1040:1,1080:9,1142:1,1232:1,1366:1,1409:1,1412:1,1537:1,1545:1,1597:1,1841:2,1861:1,1901:1,1907:1,2063:1,2097:1,2167:1,2198:1,2221:1,2468:1,2498:1,2595:1,2698:1,2975:1,2990:1,2996:1,3256:1,3267:1,3316:2,3355:1,4198:1,4356:1,4738:1,4845:1\n'

# %%
song_info           #Information of the First Song
# Out:
# ['TRZZZYX128F92D32C6',
#  '681124',
#  '1:4',
#  '2:18',
#  '4:3',
#  '5:6',
#  '6:9',
#  '7:1',
#  '8:5',
#  '9:1',
#  '10:12',
#  '11:2',
#  '12:9',
#  '13:5',
#  '15:4',
#  '17:2',
#  '18:4',
#  '19:4',
#  '21:2',
#  '22:3',
#  '25:3',
#  '29:2',
#  '30:3',
#  '32:5',
#  '34:3',
#  '35:2',
#  '37:2',
#  '39:3',
#  '43:2',
#  '44:7',
#  '45:2',
#  '49:2',
#  '50:2',
#  '52:8',
#  '54:2',
#  '56:1',
#  '59:1',
#  '63:10',
#  '64:1',
#  '66:1',
#  '71:2',
#  '72:1',
#  '78:1',
#  '79:1',
#  '84:2',
#  '91:1',
#  '92:2',
#  '95:1',
#  '96:1',
#  '103:1',
#  '110:1',
#  '115:1',
#  '127:1',
#  '134:4',
#  '135:2',
#  '136:3',
#  '137:1',
#  '138:2',
#  '140:1',
#  '146:2',
#  '150:1',
#  '152:1',
#  '192:1',
#  '206:1',
#  '207:1',
#  '222:3',
#  '239:1',
#  '248:2',
#  '258:1',
#  '270:1',
#  '274:1',
#  '283:1',
#  '294:2',
#  '300:1',
#  '305:1',
#  '318:1',
#  '337:1',
#  '338:1',
#  '346:1',
#  '347:1',
#  '349:1',
#  '371:1',
#  '398:1',
#  '406:1',
#  '445:1',
#  '451:1',
#  '459:1',
#  '478:1',
#  '487:1',
#  '492:1',
#  '502:3',
#  '516:1',
#  '539:1',
#  '548:2',
#  '549:1',
#  '553:1',
#  '592:2',
#  '617:1',
#  '633:1',
#  '666:1',
#  '681:1',
#  '727:1',
#  '774:1',
#  '775:7',
#  '789:1',
#  '811:1',
#  '844:1',
#  '915:1',
#  '942:1',
#  '950:1',
#  '979:1',
#  '1008:1',
#  '1040:1',
#  '1080:9',
#  '1142:1',
#  '1232:1',
#  '1366:1',
#  '1409:1',
#  '1412:1',
#  '1537:1',
#  '1545:1',
#  '1597:1',
#  '1841:2',
#  '1861:1',
#  '1901:1',
#  '1907:1',
#  '2063:1',
#  '2097:1',
#  '2167:1',
#  '2198:1',
#  '2221:1',
#  '2468:1',
#  '2498:1',
#  '2595:1',
#  '2698:1',
#  '2975:1',
#  '2990:1',
#  '2996:1',
#  '3256:1',
#  '3267:1',
#  '3316:2',
#  '3355:1',
#  '4198:1',
#  '4356:1',
#  '4738:1',
#  '4845:1\n']

# %%
MSDID             # Track ID
# Out:
# 'TRZZZYX128F92D32C6'

# %%
song_bow         # List of Word Index along with Word Count
# Out:
# [['1', '4'],
#  ['2', '18'],
#  ['4', '3'],
#  ['5', '6'],
#  ['6', '9'],
#  ['7', '1'],
#  ['8', '5'],
#  ['9', '1'],
#  ['10', '12'],
#  ['11', '2'],
#  ['12', '9'],
#  ['13', '5'],
#  ['15', '4'],
#  ['17', '2'],
#  ['18', '4'],
#  ['19', '4'],
#  ['21', '2'],
#  ['22', '3'],
#  ['25', '3'],
#  ['29', '2'],
#  ['30', '3'],
#  ['32', '5'],
#  ['34', '3'],
#  ['35', '2'],
#  ['37', '2'],
#  ['39', '3'],
#  ['43', '2'],
#  ['44', '7'],
#  ['45', '2'],
#  ['49', '2'],
#  ['50', '2'],
#  ['52', '8'],
#  ['54', '2'],
#  ['56', '1'],
#  ['59', '1'],
#  ['63', '10'],
#  ['64', '1'],
#  ['66', '1'],
#  ['71', '2'],
#  ['72', '1'],
#  ['78', '1'],
#  ['79', '1'],
#  ['84', '2'],
#  ['91', '1'],
#  ['92', '2'],
#  ['95', '1'],
#  ['96', '1'],
#  ['103', '1'],
#  ['110', '1'],
#  ['115', '1'],
#  ['127', '1'],
#  ['134', '4'],
#  ['135', '2'],
#  ['136', '3'],
#  ['137', '1'],
#  ['138', '2'],
#  ['140', '1'],
#  ['146', '2'],
#  ['150', '1'],
#  ['152', '1'],
#  ['192', '1'],
#  ['206', '1'],
#  ['207', '1'],
#  ['222', '3'],
#  ['239', '1'],
#  ['248', '2'],
#  ['258', '1'],
#  ['270', '1'],
#  ['274', '1'],
#  ['283', '1'],
#  ['294', '2'],
#  ['300', '1'],
#  ['305', '1'],
#  ['318', '1'],
#  ['337', '1'],
#  ['338', '1'],
#  ['346', '1'],
#  ['347', '1'],
#  ['349', '1'],
#  ['371', '1'],
#  ['398', '1'],
#  ['406', '1'],
#  ['445', '1'],
#  ['451', '1'],
#  ['459', '1'],
#  ['478', '1'],
#  ['487', '1'],
#  ['492', '1'],
#  ['502', '3'],
#  ['516', '1'],
#  ['539', '1'],
#  ['548', '2'],
#  ['549', '1'],
#  ['553', '1'],
#  ['592', '2'],
#  ['617', '1'],
#  ['633', '1'],
#  ['666', '1'],
#  ['681', '1'],
#  ['727', '1'],
#  ['774', '1'],
#  ['775', '7'],
#  ['789', '1'],
#  ['811', '1'],
#  ['844', '1'],
#  ['915', '1'],
#  ['942', '1'],
#  ['950', '1'],
#  ['979', '1'],
#  ['1008', '1'],
#  ['1040', '1'],
#  ['1080', '9'],
#  ['1142', '1'],
#  ['1232', '1'],
#  ['1366', '1'],
#  ['1409', '1'],
#  ['1412', '1'],
#  ['1537', '1'],
#  ['1545', '1'],
#  ['1597', '1'],
#  ['1841', '2'],
#  ['1861', '1'],
#  ['1901', '1'],
#  ['1907', '1'],
#  ['2063', '1'],
#  ['2097', '1'],
#  ['2167', '1'],
#  ['2198', '1'],
#  ['2221', '1'],
#  ['2468', '1'],
#  ['2498', '1'],
#  ['2595', '1'],
#  ['2698', '1'],
#  ['2975', '1'],
#  ['2990', '1'],
#  ['2996', '1'],
#  ['3256', '1'],
#  ['3267', '1'],
#  ['3316', '2'],
#  ['3355', '1'],
#  ['4198', '1'],
#  ['4356', '1'],
#  ['4738', '1'],
#  ['4845', '1\n']]

# %%
song_msd_ids = list(all_songs_dict.keys())              #Track ID of All Songs
song_msd_ids
# Out:
# ['TRAAAAV128F421A322',
#  'TRAAABD128F429CF47',
#  'TRAAAED128E0783FAB',
#  'TRAAAEF128F4273421',
#  'TRAAAEW128F42930C0',
#  'TRAAAFD128F92F423A',
#  'TRAAAGF12903CEC202',
#  'TRAAAHJ128F931194C',
#  'TRAAAHZ128E0799171',
#  'TRAAAJG128F9308A25',
#  'TRAAAOF128F429C156',
#  'TRAAARJ128F9320760',
#  'TRAAAUC128F428716F',
#  'TRAAAZF12903CCCF6B',
#  'TRAABEV12903CC53A4',
#  'TRAABHB12903CAFC2F',
#  'TRAABHC128F933A3F8',
#  'TRAABIG128F9356C56',
#  'TRAABJS128F9325C99',
#  'TRAABJV128F1460C49',
#  'TRAABLR128F423B7E3',
#  'TRAABOA128F933684A',
#  'TRAABOG128F42955B1',
#  'TRAABPG128F14774DD',
#  'TRAABVM128F92CA9DC',
#  'TRAABXH128F42955D6',
#  'TRAACER128F4290F96',
#  'TRAACFV128F935E50B',
#  'TRAACHN128F1489601',
#  'TRAACIE128F428495B',
#  'TRAACIR128F42963AC',
#  'TRAACJC128F934ABB5',
#  'TRAACPH12903CF5F14',
#  'TRAACQW128F428854F',
#  'TRAACRY12903CAF2C2',
#  'TRAACUP128E0789C69',
#  'TRAACZN128F93236B1',
#  'TRAADAA128F92F7043',
#  'TRAADBN128F932D00A',
#  'TRAADCQ128F93436C3',
#  'TRAADKA12903CD2511',
#  'TRAADKW128E079503A',
#  'TRAADKZ128F149BDFF',
#  'TRAADLH12903CA70EE',
#  'TRAADNA128F9331246',
#  'TRAADNL128F14519DF',
#  'TRAADNN128F42B1D94',
#  'TRAADQL128F427D281',
#  'TRAADQX128F422B4CF',
#  'TRAADSV128F42BC36A',
#  'TRAADVO128E07999E9',
#  'TRAADYB128F92D7E73',
#  'TRAADYI128E078FB38',
#  'TRAAEDY12903CBBFA7',
#  'TRAAEEQ128F42180B2',
#  'TRAAEHW128F9344FD3',
#  'TRAAEJH128E0785506',
#  'TRAAEJV128F423CF04',
#  'TRAAENC128F1451DE9',
#  'TRAAENM128EF33EDAA',
#  'TRAAEPG128F429139A',
#  'TRAAERZ128F1496921',
#  'TRAAETC12903CC4839',
#  'TRAAFEU128E078581C',
#  'TRAAFFI128F4258B77',
#  'TRAAFGQ128F427D884',
#  'TRAAFMS128F933AB23',
#  'TRAAFOH128E078BD7E',
#  'TRAAFPW128F92E2555',
#  'TRAAFRM128F9320F58',
#  'TRAAFTE128F429545F',
#  'TRAAFUJ128F933F42B',
#  'TRAAGAM128F428DCBE',
#  'TRAAGCG128F421CC9F',
#  'TRAAGCZ128F93210FD',
#  'TRAAGDX128F92C20A1',
#  'TRAAGEC128E079252C',
#  'TRAAGGE128F9325E2C',
#  'TRAAGHM128EF35CF8E',
#  'TRAAGIJ128F933430E',
#  'TRAAGIU128F931BA5B',
#  'TRAAGJV128F1464090',
#  'TRAAGMJ12903CAD7D4',
#  'TRAAGNS128E07824BD',
#  'TRAAGOZ128F92EB3D4',
#  'TRAAGPF12903CE027E',
#  'TRAAGPJ128F428CD1B',
#  'TRAAGSG128F92CFC6E',
#  'TRAAGTO128F1497E3C',
#  'TRAAGVM128E0784D95',
#  'TRAAGWV12903CF3709',
#  'TRAAGXU12903C9BE30',
#  'TRAAHBS128F429F76A',
#  'TRAAHBU12903CB9E27',
#  'TRAAHCO128F14B0844',
#  'TRAAHDK128F423BB26',
#  'TRAAHDM128F429C0B1',
#  'TRAAHEG128E07861C3',
#  'TRAAHER128F92D0354',
#  'TRAAHFR12903CA2491',
#  'TRAAHHZ128F429B6E5',
#  'TRAAHOA128F425A4F7',
#  'TRAAHOQ12903CC6A5A',
#  'TRAAHOW12903D00E51',
#  'TRAAHPF128F424091D',
#  'TRAAHRF128F92FE234',
#  'TRAAHSY128F147BB5C',
#  'TRAAHWZ128F4269B1F',
#  'TRAAHYI12903CD4ED2',
#  'TRAAHYK128F932A08F',
#  'TRAAHZP12903CA25F4',
#  'TRAAHZU128F147C1C5',
#  'TRAAHZY128F422315A',
#  'TRAAIAE128F42AC53D',
#  'TRAAIAX128F930531B',
#  'TRAAIBF128F4282493',
#  'TRAAIDR128F145A5C2',
#  'TRAAIHL128F92E6DDA',
#  'TRAAIIA128F92C2273',
#  'TRAAIII128F427D5D8',
#  'TRAAIKA128F426D3BB',
#  'TRAAIMC128F42625C6',
#  'TRAAIUJ128F42930A6',
#  'TRAAJAC128F148B530',
#  'TRAAJBP12903CC459C',
#  'TRAAJEK128F422F55A',
#  'TRAAJJA12903CC518A',
#  'TRAAJJG128F4284B27',
#  'TRAAJJI128F933E890',
#  'TRAAJJO128F426B6AE',
#  'TRAAJJW128F4298683',
#  'TRAAJJW12903CBDDCB',
#  'TRAAJKJ128F92FB44F',
#  'TRAAJMH128E0785407',
#  'TRAAJOU128E07872DF',
#  'TRAAJRN128F92EFDDB',
#  'TRAAJTE128F9321F43',
#  'TRAAJUM128F424E174',
#  'TRAAJUT12903CF126E',
#  'TRAAJXX128F4239802',
#  'TRAAJYJ128F9311839',
#  'TRAAJYK128F9334E51',
#  'TRAAJYX128F4255568',
#  'TRAAKAS128F4246013',
#  'TRAAKBQ12903CACE08',
#  'TRAAKHQ128F4289A3F',
#  'TRAAKJK12903CB660B',
#  'TRAAKJU128F42667AC',
#  'TRAAKMS12903CDCF78',
#  'TRAAKMX128F934B494',
#  'TRAAKRN128F92FF8D0',
#  'TRAAKSY128F930CA3E',
#  'TRAAKTS128F429F622',
#  'TRAAKUC128F934FDDE',
#  'TRAAKXQ12903CC0143',
#  'TRAAKZS128F426AEAF',
#  'TRAALAH128E078234A',
#  'TRAALBU128F92EC05A',
#  'TRAALDI128EF35F6DD',
#  'TRAALGY12903CBA247',
#  'TRAALKB128F930B65D',
#  'TRAALNZ128F934B373',
#  'TRAALOF128F427FE6B',
#  'TRAALRQ128F92CF1A4',
#  'TRAALSG128F42B180D',
#  'TRAALUZ128F932B42B',
#  'TRAALWY128F423EE73',
#  'TRAALWZ128F930A4F0',
#  'TRAALYN128F1452482',
#  'TRAAMAI128F426A0AD',
#  'TRAAMCQ128F4259A2F',
#  'TRAAMDH12903CCF659',
#  'TRAAMES128F42AF068',
#  'TRAAMFF12903CE8107',
#  'TRAAMFG128F92FDEA2',
#  'TRAAMJP128F9302722',
#  'TRAAMLN128F92F9634',
#  'TRAAMPA128F92E7D0D',
#  'TRAAMRO128F92F20D7',
#  'TRAAMXN128F148AD52',
#  'TRAAMYQ128F148B753',
#  'TRAANBH128F9345A6C',
#  'TRAANCP128F426A9B7',
#  'TRAANDL128F425A4F2',
#  'TRAANFL12903CC4730',
#  'TRAANIX128F92DF5E3',
#  'TRAANJF12903CF11A0',
#  'TRAANND128F930CCC1',
#  'TRAANQG12903D00D4F',
#  'TRAANRJ128F931D72D',
#  'TRAANRS128F92E4F27',
#  'TRAANWE128F933478D',
#  'TRAANYI12903CF5C63',
#  'TRAAOFS128F9309414',
#  'TRAAOGR128F425E7BF',
#  'TRAAOIH128F92F0679',
#  'TRAAOIK128F424BFED',
#  'TRAAOIN128F9303790',
#  'TRAAOJI128F1458DCD',
#  'TRAAORZ128F421CB5C',
#  'TRAAOYG128F9314996',
#  'TRAAOYP128F425EEB5',
#  'TRAAOZS128F4283694',
#  'TRAAPAU128F92DB7ED',
#  'TRAAPCC128F42519A7',
#  'TRAAPFE12903CF5DF4',
#  'TRAAPGF128F1458F8B',
#  'TRAAPGS128F42431B2',
#  'TRAAPHH128F145D947',
#  'TRAAPIV128F1493132',
#  'TRAAPKC128F4239298',
#  'TRAAPKS128F92F9047',
#  'TRAAPKW128F428BC93',
#  'TRAAPMC128F424BAD2',
#  'TRAAPNM128F4280813',
#  'TRAAPPH128F428B0B7',
#  'TRAAPPQ128F14961F5',
#  'TRAAPQX128F1473252',
#  'TRAAPSN128F422B2F7',
#  'TRAAPSY128F92F5706',
#  'TRAAPUG128F148955D',
#  'TRAAQAL128F92EA7A7',
#  'TRAAQBF12903CF796B',
#  'TRAAQCK128F92E8C33',
#  'TRAAQCV128F9327B59',
#  'TRAAQFS128E07878C4',
#  'TRAAQGK12903CD54B7',
#  'TRAAQIH128F428BDEA',
#  'TRAAQJO128F92E9DD0',
#  'TRAAQLF128F427822C',
#  'TRAAQTM128F426B6E6',
#  'TRAAQUC128F9322A82',
#  'TRAAQUU128F42901ED',
#  'TRAAQVX128F14958EB',
#  'TRAAQVX128F42B11B5',
#  'TRAAQXO128F933E779',
#  'TRAAQXU128F92DC056',
#  'TRAAQZQ128EF35C51A',
#  'TRAARFN12903D08A8C',
#  'TRAARMW128F424A387',
#  'TRAARQN128E07894DF',
#  'TRAARRM128F42BC439',
#  'TRAARSF12903CD1B12',
#  'TRAARXB128F92FA0BF',
#  'TRAARXD12903D0CF24',
#  'TRAARYN128F92D687A',
#  'TRAASAU12903CF6274',
#  'TRAASBR128F92F2CEF',
#  'TRAASER128F4248892',
#  'TRAASES128F92EEC4C',
#  'TRAASFP128F42980BD',
#  'TRAASGM128EF34DBB0',
#  'TRAASHC128F427ED9F',
#  'TRAASJJ128F933E26E',
#  'TRAASKR128F92DF3D1',
#  'TRAASQC128F93480F0',
#  'TRAASTP128F4294FD9',
#  'TRAASUZ128F9314950',
#  'TRAASYQ128F930E0FE',
#  'TRAATFW128F14957A8',
#  'TRAATIP12903CB1B56',
#  'TRAATIU128F4291A84',
#  'TRAATJP12903CBA7D7',
#  'TRAATKF128E0786B4B',
#  'TRAATLN128F425399A',
#  'TRAATMI128F9366CA1',
#  'TRAATMY128F149562F',
#  'TRAATNJ128F42631BA',
#  'TRAATPA128F146753C',
#  'TRAATPB128C719688E',
#  'TRAATUB128F9341737',
#  'TRAATVN128F92F42CE',
#  'TRAATZX128F92D1DD3',
#  'TRAATZY128F428249B',
#  'TRAAUBG128F421C7F9',
#  'TRAAUCV12903CCE66A',
#  'TRAAUEO128E0780CB9',
#  'TRAAUFV128EF35F02C',
#  'TRAAUGD128F42734DA',
#  'TRAAUIP128F4242B6D',
#  'TRAAULB128F4270576',
#  'TRAAUMN128F4273561',
#  'TRAAUMZ128E0796151',
#  'TRAAUNE128F92D81BA',
#  'TRAAUQF12903CC4A4D',
#  'TRAAUZX128F92F3D53',
#  'TRAAVBL128F426B7CD',
#  'TRAAVBM128F9315516',
#  'TRAAVDV128F931F2A3',
#  'TRAAVEY128F9342A2B',
#  'TRAAVGB12903CFAA99',
#  'TRAAVOK12903CC4773',
#  'TRAAVOU128F422F292',
#  'TRAAVPC12903CF7C01',
#  'TRAAVQV128F148DFEF',
#  'TRAAVRJ128F92FF90A',
#  'TRAAVRU128F423EAE2',
#  'TRAAVVO128E0796144',
#  'TRAAWAY128F92C38BF',
#  'TRAAWBV128F148BCDB',
#  'TRAAWBZ128F42BA8C0',
#  'TRAAWEH128F4285CCE',
#  'TRAAWGY128F4298A09',
#  'TRAAWHT128F427072D',
#  'TRAAWJJ128F92DE35F',
#  'TRAAWNH12903D13DC7',
#  'TRAAWOR128F92DF3C8',
#  'TRAAWPM128F1468260',
#  'TRAAWQD12903CAA968',
#  'TRAAWVV12903CE827E',
#  'TRAAWXT128F930FC84',
#  'TRAAWYC128F1489A60',
#  'TRAAWZV128F42BC229',
#  'TRAAXIR128F92D1938',
#  'TRAAXLX128F147DDA9',
#  'TRAAXMX128F9307699',
#  'TRAAXPX128F42AA93D',
#  'TRAAXSY128F426F4EA',
#  'TRAAXUD128F4259FAA',
#  'TRAAXUY128F426BA55',
#  'TRAAXVE128F1458ABA',
#  'TRAAXXE128F9329846',
#  'TRAAXZC128F9360095',
#  'TRAAYPN128F9340DDF',
#  'TRAAYQS128F145E705',
#  'TRAAYRC128F428DCA3',
#  'TRAAYUZ128F9312AA8',
#  'TRAAYVI128F4286706',
#  'TRAAYVR128F9311372',
#  'TRAAYWC12903CEA796',
#  'TRAAYXE128F4289CA7',
#  'TRAAYXM128F92E3B09',
#  'TRAAYXZ12903CD49B4',
#  'TRAAYYG12903CFC990',
#  'TRAAZBD128F427A97D',
#  'TRAAZGC12903CB5DFB',
#  'TRAAZHM128EF342709',
#  'TRAAZHV128F428FD1D',
#  'TRAAZKA128F4261CE1',
#  'TRAAZKS12903CF5395',
#  'TRAAZKV12903CDDFE0',
#  'TRAAZNV128EF358479',
#  'TRAAZPQ128F4276442',
#  'TRAAZQS12903CA1957',
#  'TRAAZQW128F93430DC',
#  'TRAAZYY128F9358638',
#  'TRABAAX128F14914F9',
#  'TRABAFJ128F42AF24E',
#  'TRABAHX128F42624F6',
#  'TRABAIQ128F42A236F',
#  'TRABAIU128F425564B',
#  'TRABAKG128F4262750',
#  'TRABAKX128F92C1D3D',
#  'TRABAPE128F4252F0E',
#  'TRABARB128F147EEEC',
#  'TRABAWI128F424F105',
#  'TRABAWQ128E0783C6F',
#  'TRABAYJ128F92E34EC',
#  'TRABAZY128F429205B',
#  'TRABBCB128F428EEF7',
#  'TRABBGS128F934EE17',
#  'TRABBHI128F426260D',
#  'TRABBJS128F934535B',
#  'TRABBKF128F93359AC',
#  'TRABBOP128F931B50D',
#  'TRABBQH12903CF19BC',
#  'TRABBUN12903CB80F0',
#  'TRABBXU128F92FEF48',
#  'TRABBXV12903CA7C77',
#  'TRABBZM128F426782A',
#  'TRABCAK128F931B482',
#  'TRABCBC12903CEDA2C',
#  'TRABCEE12903CB19B3',
#  'TRABCHK12903CD0710',
#  'TRABCIX128F4265903',
#  'TRABCJC128F42759B7',
#  'TRABCKA128F42858F6',
#  'TRABCKL128F423A778',
#  'TRABCPG128F42466F3',
#  'TRABCTR12903D08121',
#  'TRABCWK128F42BBC0B',
#  'TRABDAA12903CF45CB',
#  'TRABDGA128F4228CFF',
#  'TRABDIN128F427AF69',
#  'TRABDJI128F14567D2',
#  'TRABDKD128F9344555',
#  'TRABDMG128F421EB17',
#  'TRABDPR128F9326104',
#  'TRABDQB12903CF053F',
#  'TRABDTV128E0791839',
#  'TRABDWE128F92D1288',
#  'TRABDWS12903CE801C',
#  'TRABEAE12903CDD8EE',
#  'TRABEBP12903C9BA03',
#  'TRABEEJ12903C9748C',
#  'TRABEIF128F4280C79',
#  'TRABEIU128F4266CC2',
#  'TRABEJF128F930EAD8',
#  'TRABEKF128F42765FF',
#  'TRABESY128F935A564',
#  'TRABEXF128F92E8031',
#  'TRABEXK12903CCE19B',
#  'TRABEZK128F42974A1',
#  'TRABFEL128F931FD79',
#  'TRABFKN12903CAF61B',
#  'TRABFKZ128F146375F',
#  'TRABFMD128F9305DFC',
#  'TRABFNK128EF34FA66',
#  'TRABFOS128F4282120',
#  'TRABFPG128F423EDEF',
#  'TRABFSY128F42866CE',
#  'TRABFUN128F1456BAC',
#  'TRABFWG128F92EA530',
#  'TRABFWK128F9322F59',
#  'TRABFWY128F4273ADC',
#  'TRABFZX128F4241355',
#  'TRABGCD128F42884EB',
#  'TRABGCE128F422E38E',
#  'TRABGGZ12903CB5335',
#  'TRABGHG128F934B27E',
#  'TRABGIN128F14B0238',
#  'TRABGLK128F9338730',
#  'TRABGLR12903CEEFEA',
#  'TRABGMB12903CF50FE',
#  'TRABGMC12903CFA8C5',
#  'TRABGNX128F92ECF1C',
#  'TRABGUY128F426654F',
#  'TRABGWU12903CB502B',
#  'TRABGYE128E078278A',
#  'TRABHAT128F1464F13',
#  'TRABHBA128F424CF80',
#  'TRABHBA128F425CEC5',
#  'TRABHDD128F42AA323',
#  'TRABHRE128F4243BEF',
#  'TRABHTT128F92E01EB',
#  'TRABHTY12903CCE195',
#  'TRABHTZ128F4281913',
#  'TRABHVL128F92EFB0E',
#  'TRABHVY12903CE7082',
#  'TRABHWT128F4296097',
#  'TRABHWW128F424E9D2',
#  'TRABIAL128F42684DC',
#  'TRABIAS128F426351C',
#  'TRABIDU12903CE95D9',
#  'TRABIPA128F1458F79',
#  'TRABIRM128F92CA303',
#  'TRABISN12903D0A0E0',
#  'TRABITQ12903CAC6A8',
#  'TRABIVC128F934B524',
#  'TRABIVW12903CFC962',
#  'TRABIZY128F933C696',
#  'TRABJIX128C7196953',
#  'TRABJQF12903CE85D6',
#  'TRABJRD128F427D63D',
#  'TRABJWA128F9309C09',
#  'TRABJWR128EF349A3C',
#  'TRABJYG128F92EB8DC',
#  'TRABKAR12903CF6A60',
#  'TRABKBS128F42823EC',
#  'TRABKEC128F424DF63',
#  'TRABKGX128F92C2AB8',
#  'TRABKIS128F42682B2',
#  'TRABKJV128F92E9965',
#  'TRABKOF128F930AC23',
#  'TRABKPP128F4242E5C',
#  'TRABKQK12903CC46D0',
#  'TRABKRM128EF353DF3',
#  'TRABKSY128F429DE2A',
#  'TRABLCE128F9350C11',
#  'TRABLGI128F42B867A',
#  'TRABLGN128F933D417',
#  'TRABLIP128F930C032',
#  'TRABLKI128F4293C9B',
#  'TRABLLC128F427F42F',
#  'TRABLLK128F428FFAF',
#  'TRABLMN128E0792687',
#  'TRABLMR128F9329D40',
#  'TRABLOG128F933A4C1',
#  'TRABLQE128F92E5E75',
#  'TRABLRB12903CDD073',
#  'TRABLRC128F42930A1',
#  'TRABLSA128F4277BD6',
#  'TRABLSP128F92F0E1D',
#  'TRABLTI12903D081EA',
#  'TRABLTJ128F4231138',
#  'TRABLTP128F930DC6D',
#  'TRABLTT128F428B03E',
#  'TRABLYQ128F429A9F8',
#  'TRABLYZ128F427C6F8',
#  'TRABMBG128F429E9F1',
#  'TRABMEM12903CB1A75',
#  'TRABMGL128F425A5C8',
#  'TRABMIV128F9312391',
#  'TRABMIY128F426EA8F',
#  'TRABMMM128F429199D',
#  'TRABMPO12903CA4BDC',
#  'TRABMSV128F42684C9',
#  'TRABMXO128F145AFE1',
#  'TRABMZZ128F4249C60',
#  'TRABNAL128F9327309',
#  'TRABNDS128F93236DD',
#  'TRABNET128F14560AC',
#  'TRABNEX128F92C9DEA',
#  'TRABNGY128F421A578',
#  'TRABNHX128F4275E7B',
#  'TRABNIR128F424DDD9',
#  'TRABNLE128EF34B85D',
#  'TRABNOI12903CD99A0',
#  'TRABNPV128F427EF53',
#  'TRABNRF128F42712C0',
#  'TRABNTM128F42A2713',
#  'TRABNVL128F14A9685',
#  'TRABNVP128E0787248',
#  'TRABNWP128F93126D4',
#  'TRABNZK128F42AB221',
#  'TRABNZR128EF353CD8',
#  'TRABNZS128F932C6E8',
#  'TRABOCK12903CDBA6A',
#  'TRABODU128F427F102',
#  'TRABOEC128F4268D43',
#  'TRABOFS128F429AE4C',
#  'TRABOGP12903CC080D',
#  'TRABOIH128F9300B06',
#  'TRABOMA128F9343A21',
#  'TRABOMC128F149BA5A',
#  'TRABONE12903CDFFE7',
#  'TRABOOC128F92D2D90',
#  'TRABOOL128F426E836',
#  'TRABOPN128F92F6C2B',
#  'TRABOQX128F427A4A1',
#  'TRABOTO12903CDF879',
#  'TRABOVH128F427D3B4',
#  'TRABOVR12903CA8488',
#  'TRABOWL128F427B697',
#  'TRABOXX128F92F29EB',
#  'TRABPAN12903CDCAAD',
#  'TRABPAU128F429C1BD',
#  'TRABPAY128F428B181',
#  'TRABPDM128EF34E32D',
#  'TRABPGO128F931B50C',
#  'TRABPHE128F42A1E65',
#  'TRABPJW128F147295E',
#  'TRABPKD128F9338BFB',
#  'TRABPMR128F92F121B',
#  'TRABPNC128F92CC869',
#  'TRABPNQ12903CF544B',
#  'TRABPNV128F1476532',
#  'TRABPPP128F9320BFF',
#  'TRABPRT128F1495762',
#  'TRABPSU128EF34ACF8',
#  'TRABPUI12903CF22CE',
#  'TRABPUP128F92C90BA',
#  'TRABPWB128F42BAF33',
#  'TRABQBB12903CFD752',
#  'TRABQCU128F4263E52',
#  'TRABQGZ128F14974A3',
#  'TRABQHW128F425D9D4',
#  'TRABQOJ128F9316C75',
#  'TRABQTA128F148D048',
#  'TRABQUH128F424E5D2',
#  'TRABQUM12903C9A618',
#  'TRABQUU128F932674B',
#  'TRABQVF128E0787874',
#  'TRABQYN128F14ADBCF',
#  'TRABQZK128F92F54F4',
#  'TRABQZO128F92EE566',
#  'TRABRFP128F42B7B7A',
#  'TRABRHT12903CF274F',
#  'TRABRMJ128E0780E42',
#  'TRABRMZ128F4261DED',
#  'TRABRQY12903CA5133',
#  'TRABRRK128F14554B0',
#  'TRABRRN12903CF084B',
#  'TRABRTC128E0784ECC',
#  'TRABRTO12903CE53B6',
#  'TRABRUJ128F42ADE0D',
#  'TRABRVU128EF342D09',
#  'TRABRYD128F42675A9',
#  'TRABSAR128F42324A8',
#  'TRABSBK128F4292BB0',
#  'TRABSEN128F424AA36',
#  'TRABSPE128F92EC08F',
#  'TRABSVD12903CCAA52',
#  'TRABSVM128F931D982',
#  'TRABTCS12903CDE029',
#  'TRABTCY12903C9402E',
#  'TRABTDI12903CC506C',
#  'TRABTDP128F424D00B',
#  'TRABTJM128F4276BC8',
#  'TRABTJR128F92E4D4E',
#  'TRABTKG128F4283191',
#  'TRABTMV128F4292B89',
#  'TRABTOV12903CA8931',
#  'TRABTQB128F42269BD',
#  'TRABTQF128F4265010',
#  'TRABTWX128F42B8619',
#  'TRABTXQ12903CD7862',
#  'TRABTXS128F92E2FDC',
#  'TRABTYE12903CDA646',
#  'TRABTZG12903CF1339',
#  'TRABTZM128F9328FEC',
#  'TRABUAQ128F4262390',
#  'TRABUBB128F1469DE8',
#  'TRABUDK128F14943F3',
#  'TRABUEG12903CF57FD',
#  'TRABUFB12903CFE0F9',
#  'TRABUIN128F93022FF',
#  'TRABULB128F42840B1',
#  'TRABUSV12903C9899E',
#  'TRABUUB128E07872C3',
#  'TRABUUH128F4241346',
#  'TRABUVN128F930633C',
#  'TRABUWB128E0788915',
#  'TRABUWT128F4242FD2',
#  'TRABUXE12903D16619',
#  'TRABUXL128F149DFDD',
#  'TRABUXL128F42630D2',
#  'TRABUZC128E078603F',
#  'TRABVIF128F42ABB3B',
#  'TRABVIR128F4273F22',
#  'TRABVMH128F146467B',
#  'TRABVMZ12903CD1EBA',
#  'TRABVQA128F4236CF8',
#  'TRABVQF128F42591BF',
#  'TRABVSH128F92C3F3F',
#  'TRABVSR128EF35C46C',
#  'TRABVTF12903D0F87F',
#  'TRABVTG128F934AB80',
#  'TRABVVT128F931853E',
#  'TRABVWG128F9359323',
#  'TRABWAZ12903D0539E',
#  'TRABWIC12903CC24C5',
#  'TRABWJX128F425A2AE',
#  'TRABWLM128F92EC20D',
#  'TRABWNZ12903CB6116',
#  'TRABWPT128F42B06CC',
#  'TRABXBI128F933D661',
#  'TRABXDT12903D07306',
#  'TRABXLH128F935F8E7',
#  'TRABXPK128F9336565',
#  'TRABXPR128F92F27FE',
#  'TRABXRU128F14A19A6',
#  'TRABXRX128F425C752',
#  'TRABXTA128F14AE8C5',
#  'TRABXVE128F4284AFC',
#  'TRABXWC128F92CF313',
#  'TRABXWX128F92FB9DF',
#  'TRABXYD128F42BB4E1',
#  'TRABYAR128F931B1A4',
#  'TRABYEE128F4242947',
#  'TRABYEY128F933773A',
#  'TRABYNV128F42622D3',
#  'TRABYOS12903CC4A81',
#  'TRABYQX128F427CF08',
#  'TRABYVN128F429E5CF',
#  'TRABZAR128F42989E0',
#  'TRABZCL128E0789AED',
#  'TRABZDM128F92FE791',
#  'TRABZFP12903D0945A',
#  'TRABZJE128F4259835',
#  'TRABZKL128F931C0CE',
#  'TRABZMU128F148643C',
#  'TRABZPG128F427A5DB',
#  'TRABZQR12903CCBE06',
#  'TRABZRZ128F42628AD',
#  'TRABZSO128F9325A05',
#  'TRABZUX128F92FC4FF',
#  'TRABZVQ128F422AC74',
#  'TRABZXS128F42634CE',
#  'TRABZYU128F93397B5',
#  'TRABZYW12903CBE4A3',
#  'TRABZZD128F9334C0B',
#  'TRACACO12903C979EC',
#  'TRACAGI128F92C41F6',
#  'TRACAGS128F4246062',
#  'TRACAJY128F92CB794',
#  'TRACAOG128F42A834C',
#  'TRACARD128F4259678',
#  'TRACASH128F931C969',
#  'TRACBED128F427B4B5',
#  'TRACBGI128F427817D',
#  'TRACBHR12903CA7C2B',
#  'TRACBLO128E0784286',
#  'TRACBPX128F9342ABA',
#  'TRACBRM128F425C2C3',
#  'TRACBSE12903CC245C',
#  'TRACBTI12903CF6F9E',
#  'TRACBUJ128F92F8279',
#  'TRACBUY128F1479245',
#  'TRACBWP128C7196948',
#  'TRACBWQ128F92F2B91',
#  'TRACBWX128F92FD725',
#  'TRACBYL12903CFDBC6',
#  'TRACBYM128F92FE7DF',
#  'TRACBZQ128F425A848',
#  'TRACCAR128F92FC89D',
#  'TRACCCQ12903CDCAEA',
#  'TRACCDH12903CE8271',
#  'TRACCDN128E0783BC1',
#  'TRACCEJ128F93257ED',
#  'TRACCFX128F428F319',
#  'TRACCII128F9350137',
#  'TRACCJA128F149A144',
#  'TRACCKD12903CA21A8',
#  'TRACCLU128F42BA41F',
#  'TRACCNE12903CD8E17',
#  'TRACCRD128F4231A76',
#  'TRACCSW128F148C7C3',
#  'TRACCVW128F92F5691',
#  'TRACCVZ128F4291A8A',
#  'TRACCWN128F4284046',
#  'TRACCWR12903CA8AF2',
#  'TRACCZB128F429077B',
#  'TRACDAN128F145E37C',
#  'TRACDAS128F92D7304',
#  'TRACDBI128F93240EB',
#  'TRACDCZ128F4285AE0',
#  'TRACDED128F4259D38',
#  'TRACDEX128F92E994A',
#  'TRACDEY128F931D2A2',
#  'TRACDHB12903CDF8F6',
#  'TRACDHL12903D0C387',
#  'TRACDRK128F4227C32',
#  'TRACDTC128F426F7CE',
#  'TRACDUX128F429B303',
#  'TRACDUX12903CE871D',
#  'TRACDWB128F92C7A17',
#  'TRACDXT128F148248E',
#  'TRACDZX128F42967DC',
#  'TRACEAI12903CDD40B',
#  'TRACECP128F92CD1A1',
#  'TRACEDW128EF353CA4',
#  'TRACEEL12903CE4197',
#  'TRACEHO128F1488CEA',
#  'TRACEJI128E0798842',
#  'TRACEJW128F42BA8D5',
#  'TRACELQ128F92FC315',
#  'TRACENV128F9327B56',
#  'TRACEOO128F92CE318',
#  'TRACEPD128F429B0CB',
#  'TRACEQC128F92F2E17',
#  'TRACEQI128F42782EA',
#  'TRACESB128F92F0EDD',
#  'TRACETV12903CDD0F6',
#  'TRACEWM128F931E7C8',
#  'TRACEYZ128F424D66A',
#  'TRACFAP128E07862C1',
#  'TRACFDS12903CE7CC6',
#  'TRACFGY128EF34E31F',
#  'TRACFLS12903CF9950',
#  'TRACFOJ128F4253EFA',
#  'TRACFOV128F9340D81',
#  'TRACFQR128E0793D87',
#  'TRACFWQ12903CF8148',
#  'TRACFXL128F930B28B',
#  'TRACFZI128E0795424',
#  'TRACFZZ12903CA2557',
#  'TRACGAQ128F4280C47',
#  'TRACGCE128F9340F96',
#  'TRACGCT128F42BA91B',
#  'TRACGEI128F9343D35',
#  'TRACGHI128F427EC93',
#  'TRACGHT128F9336DF8',
#  'TRACGNG12903D021AE',
#  'TRACGOV128F14531E5',
#  'TRACGQQ128F92DDCE7',
#  'TRACGUQ128F932A4CB',
#  'TRACGWA128F42806FE',
#  'TRACGZY128F423F988',
#  'TRACHBJ128EF352A74',
#  'TRACHBV128F4258575',
#  'TRACHCK128F425AD97',
#  'TRACHCN128F1487F2B',
#  'TRACHFO12903CB3009',
#  'TRACHFR128F4263E07',
#  'TRACHHH128E0788A35',
#  'TRACHHY128F42A38CC',
#  'TRACHKX128F934B07A',
#  'TRACHLU128F4259F9B',
#  'TRACHRS128F423EDFB',
#  'TRACHTD12903CF5E22',
#  'TRACHWK128F428B5CA',
#  'TRACHWL128F426A203',
#  'TRACHYC128F92D7A96',
#  'TRACICJ128F14ADFB8',
#  'TRACIEP128F4246AFB',
#  'TRACIGR128F933D82C',
#  'TRACIKT128F424E34D',
#  'TRACILL12903CA3E21',
#  'TRACIQI128F92E5877',
#  'TRACIQK12903CBE181',
#  'TRACISV12903D13877',
#  'TRACIVX128F4238A63',
#  'TRACIYB128F92FE037',
#  'TRACJCZ12903CFD7C7',
#  'TRACJGH128F4266022',
#  'TRACJGW128F42369A8',
#  'TRACJHU12903CCB0C4',
#  'TRACJJC128F934AF55',
#  'TRACJLW128E079404D',
#  'TRACJOD128F931D69F',
#  'TRACJPL128F42635BB',
#  'TRACJPW128F932CA4C',
#  'TRACJWL128F92FB60E',
#  'TRACJWQ128F92E526E',
#  'TRACJWY12903CB7DBF',
#  'TRACJXV128F9301DD2',
#  'TRACJYX128F1453469',
#  'TRACJZR128F4270103',
#  'TRACKAP128F425B741',
#  'TRACKKF128F93304AD',
#  'TRACKKU128F92FDFA8',
#  'TRACKOJ128F933AFB0',
#  'TRACKUU12903C9FEF8',
#  'TRACKVZ128F4285793',
#  'TRACKWV128F934B6B0',
#  'TRACKXC128F425E92E',
#  'TRACLBE128F1485B63',
#  'TRACLCA128F92F3B12',
#  'TRACLHC128F9343C39',
#  'TRACLHK128F9326075',
#  'TRACLJK128F42954AE',
#  'TRACLMB128F429768F',
#  'TRACLNY128F4242B5B',
#  'TRACLOE12903CA7F52',
#  'TRACLRS12903CE9386',
#  'TRACLRV128EF33FAB8',
#  'TRACLWY128F145F848',
#  'TRACMAJ128F1458881',
#  'TRACMCG128F92CE225',
#  'TRACMHD128F931FB14',
#  'TRACMKU128F4263E6F',
#  'TRACMMG128F146D705',
#  'TRACMOD128F42817B3',
#  'TRACMPN128F42640BD',
#  'TRACMPX128EF345D3C',
#  'TRACMSK128F428FF9B',
#  'TRACMTQ128F92FAD03',
#  'TRACMVQ128F93069A8',
#  'TRACMXG12903CA2541',
#  'TRACMYN128F9337909',
#  'TRACNBK128F423277B',
#  'TRACNDV12903C9ABA7',
#  'TRACNDX128F427C263',
#  'TRACNEC128F428647B',
#  'TRACNEP12903CB1012',
#  'TRACNNE128F93037BC',
#  'TRACNQB128F424DF24',
#  'TRACNWH12903D08866',
#  'TRACNWM128F92FB9C0',
#  'TRACNXS128F93395BA',
#  'TRACNXU12903C9CDFF',
#  'TRACNYI128F4291FE2',
#  'TRACOFY12903CF7E97',
#  'TRACOHQ128F424C5EF',
#  'TRACOIB128F931737C',
#  'TRACOLN12903CE426A',
#  'TRACOON128F428B1B8',
#  'TRACOOY128F4270589',
#  'TRACORA128F1463731',
#  'TRACOSB128F425574A',
#  'TRACOSS12903CE4724',
#  'TRACOST128F427343D',
#  'TRACOST12903CC651E',
#  'TRACOTL128F4259193',
#  'TRACOTR128F92E16B1',
#  'TRACOTY128F930BCFA',
#  'TRACOUL128F425BDE0',
#  'TRACOYN128F9320DDF',
#  'TRACOZY128F427BE37',
#  'TRACPAM128F93359BD',
#  'TRACPCS128F425E69B',
#  'TRACPER128F92FED5C',
#  'TRACPIC128E0792500',
#  'TRACPLH128F428D852',
#  'TRACPMR128F149796B',
#  'TRACPNW128F14666EB',
#  'TRACPSV128F930AE80',
#  'TRACPUP128F932A8C9',
#  'TRACPZA128F933A56C',
#  'TRACQAU128F4284DC7',
#  'TRACQCC128F421E6E9',
#  'TRACQCI128F4262EBB',
#  'TRACQKE128F427CA3E',
#  'TRACQOD128F42A8237',
#  'TRACQQY128F1453FF4',
#  'TRACQSA128E0783B71',
#  'TRACQTN128F427CC13',
#  'TRACQZO128F4289D2D',
#  'TRACRCN128F4255F4E',
#  'TRACRHI12903CF5B31',
#  'TRACRJP128F425B83C',
#  'TRACRLM128F4250135',
#  'TRACROC12903CB5E2A',
#  'TRACRON12903CB59E6',
#  'TRACRRS128F1465A64',
#  'TRACRTR128F4287375',
#  'TRACRTS128F9300F7E',
#  'TRACRVJ128F14661D6',
#  'TRACRXO12903CB5341',
#  'TRACSBL128F42480E8',
#  'TRACSDP128F9320962',
#  'TRACSGW128F1495A28',
#  'TRACSHS128F1462A0C',
#  'TRACSIE128F427F98E',
#  'TRACSIR12903CE81A8',
#  'TRACSKH128F934020B',
#  'TRACSNO128F424F331',
#  'TRACSSJ128F92E195B',
#  'TRACSTF128F4238A87',
#  'TRACTEB128F4264605',
#  'TRACTGL128F425BEFC',
#  'TRACTHF128F4295A22',
#  'TRACTLX128F42A51F6',
#  'TRACTRN12903D0D6C2',
#  'TRACTTM128F93116B9',
#  'TRACTUA128F426AE81',
#  'TRACTUH128F92C93A3',
#  'TRACTWC128F9305C8E',
#  'TRACTWW12903CB7550',
#  'TRACTYR128EF342120',
#  'TRACUBF12903D00D33',
#  'TRACUBQ12903CF04F6',
#  'TRACUCI128F930258D',
#  'TRACUCQ128F92FFBF7',
#  'TRACUCT128F422BC2F',
#  'TRACUDO128F1469081',
#  'TRACUKY128F930A12E',
#  'TRACUVN128F426A74B',
#  'TRACUXV128F9366C7D',
#  'TRACUZC128F93328EF',
#  'TRACVBG128F42508EF',
#  'TRACVBG128F9309230',
#  'TRACVBQ128E07855EE',
#  'TRACVBT128F92F8BE2',
#  'TRACVCY128F92E742E',
#  'TRACVEO128F42B7BCF',
#  'TRACVFF12903CF055A',
#  'TRACVFQ128F149F00D',
#  'TRACVFS128F424CF67',
#  'TRACVKK128F9303A70',
#  'TRACVLU128F422B2F9',
#  'TRACVNF128F93231EB',
#  'TRACVNS12903CC1718',
#  'TRACVSS128E07846A7',
#  'TRACVSU128F933ACAC',
#  'TRACVXT128F42A092E',
#  'TRACVXY128F92F1ECA',
#  'TRACWBO128F92F322F',
#  'TRACWBP128F4260BB5',
#  'TRACWFA128F4265BDF',
#  'TRACWFX128F4267826',
#  'TRACWGP12903CA4553',
#  'TRACWWF128F9346965',
#  'TRACWXU128F429993E',
#  'TRACWYD128F1465B4A',
#  'TRACWYQ128F933917E',
#  'TRACWZJ128E078E0AC',
#  'TRACXFL128F14937DE',
#  'TRACXGH128F931686C',
#  'TRACXHD128F92E919B',
#  'TRACXKF128F14A530D',
#  'TRACXLE128F42AD932',
#  'TRACXNG128F426D754',
#  'TRACXRR128F932BDCE',
#  'TRACXWO128F423CC72',
#  'TRACXXJ128F426A02A',
#  'TRACXYU128F425EEE8',
#  'TRACYAI128F148C88C',
#  'TRACYCJ128F9309246',
#  'TRACYDP128F932BC8E',
#  'TRACYEE128F933AC6E',
#  'TRACYGX128F92F9E41',
#  'TRACYJU12903CF8041',
#  'TRACYKZ128F4265170',
#  'TRACYLE128F934B260',
#  'TRACYMH12903CA01DF',
#  'TRACYMM128F9303A59',
#  'TRACYOV128F92CB613',
#  'TRACYPB128F9343BA2',
#  'TRACYQT128F931F4C0',
#  'TRACYSI128F146CC11',
#  'TRACYUG128F4259D4C',
#  'TRACYYN12903CDEBF9',
#  'TRACYZE12903CC1B72',
#  'TRACYZL128F428305F',
#  'TRACZGB128F4262875',
#  'TRACZJA128F429E665',
#  'TRACZRN128F146E26E',
#  'TRACZVM128F423BB0A',
#  'TRACZVO128F9366E39',
#  'TRACZWR128F92FFA26',
#  'TRADAAQ128EF356987',
#  'TRADAAU128EF34DBE9',
#  'TRADABC128F4274FCC',
#  'TRADACG128F42777AC',
#  'TRADACT128F92EFE86',
#  'TRADADG128F1471351',
#  'TRADAEI128F93033D3',
#  'TRADAFY128F145B77B',
#  ...]

# %%
all_song_meta_dict = dict()

# %%
with open('/Users/mehulmadaan/Downloads/ProjectDoc2vec/mxm_779k_matches.txt','r') as data:
    lines = data.readlines()
    for i in range(18, len(lines)):             #FROM LINE 18 TO END OF FILE
        line = lines[i].split('<SEP>')
        MSDID = line[0]
        artist = line[1]
        title = line[2]
        #Makes a Nested Dictionary for Track ID, which Contains artist and title name
        all_song_meta_dict[str(MSDID)] = {'artist': artist, 'title': title}

# %%
all_song_meta_dict
# Out:
# {'TRMMMKD128F425225D': {'artist': 'Karkkiautomaatti', 'title': 'Tanssi vaan'},
#  'TRMMMRX128F93187D9': {'artist': 'Hudson Mohawke',
#   'title': 'No One Could Ever'},
#  'TRMMMCH128F425532C': {'artist': 'Yerba Brava', 'title': 'Si Vos Querés'},
#  'TRMMMXN128F42936A5': {'artist': 'David Montgomery',
#   'title': 'Symphony No. 1 G minor "Sinfonie Serieuse"/Allegro con energia'},
#  'TRMMMBB12903CB7D21': {'artist': 'Kris Kross', 'title': "2 Da Beat Ch'yall"},
#  'TRMMMHY12903CB53F1': {'artist': 'Joseph Locke', 'title': 'Goodbye'},
#  'TRMMMNS128F93548E1': {'artist': "3 Gars Su'l Sofa",
#   'title': "L'antarctique"},
#  'TRMMMXJ12903CBF111': {'artist': 'Jorge Negrete',
#   'title': 'El hijo del pueblo'},
#  'TRMMMBW128F4260CAE': {'artist': 'Tiger Lou', 'title': 'Pilots'},
#  'TRMMMXI128F4285A3F': {'artist': 'Waldemar Bastos', 'title': 'N Gana'},
#  'TRMMMKI128F931D80D': {'artist': 'Lena Philipsson', 'title': '006'},
#  'TRMMMUT128F42646E8': {'artist': 'Shawn Colvin',
#   'title': '(Looking For) The Heart Of Saturday'},
#  'TRMMMQY128F92F0EA3': {'artist': 'Dying Fetus', 'title': 'Ethos of Coercion'},
#  'TRMMMTK128F424EF7C': {'artist': 'Emery', 'title': 'Rock-N-Rule'},
#  'TRMMMQV12903CA201E': {'artist': 'Rev. Timothy Wright',
#   'title': 'I Made It Over'},
#  'TRMMMPN128F426610E': {'artist': 'Nicolette', 'title': 'Nervous'},
#  'TRMMMNO128F93539AA': {'artist': 'Martin Sexton', 'title': 'In The Journey'},
#  'TRMMMTG128F426B5BB': {'artist': 'Craze',
#   'title': 'Fuckin Ethic People (999)'},
#  'TRMMMPJ128F9306985': {'artist': 'Christian Castro',
#   'title': 'Tu Vida Con La Mía'},
#  'TRMMMRZ128F4265EB4': {'artist': 'Aerosmith', 'title': "I'm Ready"},
#  'TRMMMKD12903CF219E': {'artist': 'Skinlab', 'title': 'Take As Needed'},
#  'TRMMMJW12903CF239E': {'artist': 'Piotta', 'title': 'Tequila'},
#  'TRMMMWA128F1462C8C': {'artist': 'Sev Statik',
#   'title': 'All For A Purpose (Speak Life Album Version)'},
#  'TRMMMQN128F4238509': {'artist': 'Prince & The Revolution',
#   'title': 'Raspberry Beret (LP Version)'},
#  'TRMMMKQ128F92EBCB5': {'artist': 'Kreator', 'title': 'All of the same blood'},
#  'TRMMMQK128F428AB1F': {'artist': 'Hall Of Fame',
#   'title': 'One Little Too Little'},
#  'TRMMMPU128F42B134D': {'artist': 'Frank Chacksfield',
#   'title': 'Cockleshell Heroes'},
#  'TRMMMYP128F429A5E4': {'artist': 'Voyage', 'title': 'Trancesequence'},
#  'TRMMMKN12903CB44A5': {'artist': 'Wishbone Ash', 'title': 'Wonderful Stash'},
#  'TRMMMUZ128F4238E64': {'artist': 'Malavoi', 'title': 'La filo'},
#  'TRMMMTP128F4276193': {'artist': 'Cobra Verde', 'title': 'Throw It Away'},
#  'TRMMMSA128F425FA38': {'artist': 'Lisa Brokop',
#   'title': 'Before He Kissed Me'},
#  'TRMMMHS128F42A0971': {'artist': 'The Emotions', 'title': 'Blessed'},
#  'TRMMMDJ128F92CC9F6': {'artist': 'Hawthorne Heights',
#   'title': 'Disaster [Demo Version]'},
#  'TRMMMBU128F9305AC3': {'artist': 'The Maytals', 'title': 'Night And Day'},
#  'TRMMMFJ128F92E15AC': {'artist': 'Neffa', 'title': 'Passione'},
#  'TRMMMNI12903CE0AF1': {'artist': 'Lil\x19 O',
#   'title': 'My Everything [Screwed] (feat. Trae The Truth)'},
#  'TRMMMFG128F425087B': {'artist': 'Billy Idol', 'title': 'Scream'},
#  'TRMMMLV128F14821BE': {'artist': 'Out Of The Grey',
#   'title': 'He Is Not Silent (Out Of The Grey Album Version)'},
#  'TRMMMLF128F4228771': {'artist': 'Leo Marini', 'title': 'Acércate Más'},
#  'TRMMMXD128F932AD86': {'artist': 'Sheb Wooley', 'title': 'Mule Boogie'},
#  'TRMMMQA128F14A454A': {'artist': 'Diana Krall',
#   'title': 'Dancing In The Dark'},
#  'TRMMMGL128F92FD6AB': {'artist': 'Clifford T. Ward',
#   'title': 'Mad About You'},
#  'TRMMWMW12903CC6062': {'artist': 'Joe Diffie',
#   'title': "Ships That Don't Come In"},
#  'TRMMWDA128F9343B5B': {'artist': 'Blackfoot',
#   'title': 'Saturday Night  (LP Version)'},
#  'TRMMWDL128F9300D5D': {'artist': 'Stemm', 'title': 'On the Surface'},
#  'TRMMWJS12903CBB7F5': {'artist': 'Aerosmith',
#   'title': 'Remember (Walking In The Sand)'},
#  'TRMMWOM12903CB21B8': {'artist': 'Hot Lips Page',
#   'title': 'Just Another Woman'},
#  'TRMMWYF128F42557B7': {'artist': 'David Fridlund', 'title': 'untitled'},
#  'TRMMWZE12903D0EB43': {'artist': 'Kultiration', 'title': 'Bakslag'},
#  'TRMMWVS12903CDD6FB': {'artist': 'Ewigkeit', 'title': 'The New Way'},
#  'TRMMWCK128F92D4800': {'artist': 'Alpha 5.20',
#   'title': 'Cités dortoires (feat. 59 Grammes)'},
#  'TRMMWLD128F9301BF2': {'artist': 'Tonex', 'title': 'Bring It'},
#  'TRMMWBU128F930B7CF': {'artist': 'Finis Tasby',
#   'title': 'Sitting In My Window (Finis Tasby BMI)'},
#  'TRMMWNY12903CF28D2': {'artist': 'Warren Zevon',
#   'title': 'The Rest of the Night'},
#  'TRMMWMT128F9345B1B': {'artist': 'Andrea Klas', 'title': 'Ride'},
#  'TRMMWNB12903C9A959': {'artist': 'The Soup Dragons',
#   'title': 'Passion Protein'},
#  'TRMMWQF12903CC0CAC': {'artist': 'Write This Down', 'title': 'Redemption'},
#  'TRMMWVB128F9312434': {'artist': 'Radio Macandé', 'title': 'Dame Tus  Besos'},
#  'TRMMWNW128F931511B': {'artist': 'Brigitte Fontaine',
#   'title': 'Le mauvais coton'},
#  'TRMMWFG128F92DFAA2': {'artist': 'Hex', 'title': 'Subtek'},
#  'TRMMWPD128F4247095': {'artist': 'X-Perience', 'title': 'Dream Of Love'},
#  'TRMMWQU12903CF447F': {'artist': 'Diablo Swing Orchestra',
#   'title': 'Lucy Fears the Morning Star'},
#  'TRMMWTW128F42783DD': {'artist': 'John Williams',
#   'title': 'Fool on the Hill'},
#  'TRMMWXK12903CDED07': {'artist': 'Fucked Up', 'title': 'Baiting the Public'},
#  'TRMMWHJ128F42869B2': {'artist': 'The Surfaris', 'title': 'Wipeout'},
#  'TRMMWAO128F93182D2': {'artist': 'Kool Savas', 'title': 'Fick uns'},
#  'TRMMWVG12903CBF769': {'artist': 'Prinz Porno',
#   'title': 'Wir Sind Die Jungs feat. Din & Smexer'},
#  'TRMMWBR128F930E399': {'artist': 'Lord T & Eloise',
#   'title': 'Make Dat Monet'},
#  'TRMMWWE12903D067F2': {'artist': 'Kingdom Come', 'title': 'Two Legged Sheep'},
#  'TRMMWAO128F42A53EB': {'artist': 'Gemelli Diversi',
#   'title': 'Chi Sei Adesso'},
#  'TRMMWCX128F92EF4C8': {'artist': 'Alice In Videoland',
#   'title': 'Stuck On My Vision'},
#  'TRMMWSE128F93041C5': {'artist': 'Kristian Meurman', 'title': 'Joku muu'},
#  'TRMMWJP12903CD8807': {'artist': 'Felt', 'title': 'Whaleface (Instrumental)'},
#  'TRMMWJD12903CC0F05': {'artist': 'Gangster Fun', 'title': 'Brown Paper Bag'},
#  'TRMMWTG128F4283F07': {'artist': 'Roger Whittaker', 'title': 'You Needed Me'},
#  'TRMMWXW128F422976E': {'artist': 'A.Human', 'title': 'Pacey Singer'},
#  'TRMMWMR12903CF8643': {'artist': 'Tiësto', 'title': 'Ride'},
#  'TRMMWRF128F1462252': {'artist': 'Ice Cube Featuring Chuck D',
#   'title': 'Endangered Species (Tales From The Darkside) (Remix) (Explicit) (Feat. Chuck D)'},
#  'TRMMWJM128F4227255': {'artist': 'Archie Roach',
#   'title': 'Summer Of My Life'},
#  'TRMMWEZ128F1455EAC': {'artist': 'Lester Flatt / Earl Scruggs / The Foggy Mountain Boys',
#   'title': 'Foggy Mountain Breakdown'},
#  'TRMMWJY128F1469B8A': {'artist': 'Luis Eduardo Aute',
#   'title': 'What Matters Is Just You'},
#  'TRMMWAH128F92F9D00': {'artist': 'Lonesome River Band',
#   'title': 'Southern Comfort'},
#  'TRMMWYJ128EF358EA7': {'artist': 'Retard-O-Bot',
#   'title': 'Something From Nothing'},
#  'TRMMWWX128F92DAF12': {'artist': 'Michael Whalen', 'title': 'Half Light'},
#  'TRMMWPX128F14965B8': {'artist': 'Mark Wills',
#   'title': 'High Low And In Between'},
#  'TRMMWSG128F92DD9AB': {'artist': 'Roberto Carlos', 'title': 'Detalles'},
#  'TRMMGDQ128F4277AE7': {'artist': 'Fine China',
#   'title': "Rock Can't Last Forever  (You Hate Me Hate Music Album Version)"},
#  'TRMMGCB128E079651D': {'artist': 'Morcheeba',
#   'title': 'Get Along (Feat: Pace Won) (Instrumental)'},
#  'TRMMGQO12903CD4F19': {'artist': 'Richard "Groove" Holmes',
#   'title': 'Caravan'},
#  'TRMMGPD128F42AA230': {'artist': 'Lamb', 'title': 'Just Is'},
#  'TRMMGIL128F92DBA59': {'artist': 'DJ Markitos',
#   'title': 'Inside Your Dreams'},
#  'TRMMGTX128F92FB4D9': {'artist': 'Bacilos', 'title': 'Viejo'},
#  'TRMMGBF128F931B836': {'artist': 'Toyah',
#   'title': 'Victims of the Riddle [Vivisection]'},
#  'TRMMGBQ12903CDF86A': {'artist': 'The Wolfmen', 'title': 'Kama Sutra'},
#  'TRMMGYY128F4289515': {'artist': 'Fausto Leali',
#   'title': 'E non lo scorderò'},
#  'TRMMGHM128F4270EA7': {'artist': 'Link 80', 'title': 'What Can I Do?'},
#  'TRMMGMC12903CF7FF0': {'artist': 'Spyro Gyra', 'title': 'Pacific Sunrise'},
#  'TRMMGDG12903CDB0E8': {'artist': 'White Willow', 'title': 'Gnostalgia'},
#  'TRMMGPB128F428B04A': {'artist': 'Robbie Williams',
#   'title': 'Sin Sin Sin (Sentience Loney Mix)'},
#  'TRMMGEG12903CB4CFC': {'artist': 'Prager Handgriff', 'title': 'Bihac'},
#  'TRMMGAX128F428FD18': {'artist': 'American Boychoir',
#   'title': 'Praise_ My Soul_ The King Of Heaven'},
#  'TRMMGGP128F934AD1D': {'artist': 'Thought Industry', 'title': 'Edward Smith'},
#  'TRMMGEU12903CF009A': {'artist': 'Red Animal War', 'title': 'Dark Country'},
#  'TRMMGST128F92F25EC': {'artist': 'Lonesome River Band',
#   'title': 'Highway Paved With Pain'},
#  'TRMMGRZ12903CE1C82': {'artist': 'Jason Becker',
#   'title': 'End Of The Beginning (Album Version)'},
#  'TRMMGUF12903CB279D': {'artist': 'Sunscreem', 'title': 'Britannia'},
#  'TRMMGPI128F932E6D7': {'artist': 'Motormark',
#   'title': "I'm About To Do Something (That I'm Gonna Regret)"},
#  'TRMMGYR128F4282BAE': {'artist': 'Underworld', 'title': 'Ring Road'},
#  'TRMMGTM128F930282D': {'artist': 'Airscape', 'title': 'L\x19Esperanza'},
#  'TRMMGPL12903CCDB98': {'artist': 'Neal Morse', 'title': 'That Crutch'},
#  'TRMMGDP128F933E59A': {'artist': 'Al Green',
#   'title': 'I Say A Little Prayer'},
#  'TRMMGJZ128F4270235': {'artist': 'The Muffins', 'title': 'Dawning Star'},
#  'TRMMGKQ128F934B4CE': {'artist': 'The Funky Lowlives',
#   'title': 'Irreplaceable'},
#  'TRMMGCK128F932EC2E': {'artist': 'Brian Vander Ark',
#   'title': 'And Then You Went Away'},
#  'TRMMGKX128F421ADC1': {'artist': 'Debbie Davies',
#   'title': "You Don't Know What You're Doing"},
#  'TRMMGNC12903CABD4A': {'artist': 'Boo Hewerdine',
#   'title': "Touched (Intro: From 'That Winter' By Pamela Gillilan)"},
#  'TRMMGSH128F4243869': {'artist': 'Katatonia', 'title': 'Day'},
#  'TRMMGGU128F14A93DD': {'artist': 'Zen Cafe',
#   'title': 'En oo koskaan tavannut'},
#  'TRMMGUF12903CAFF44': {'artist': 'Warlocks', 'title': 'Militant Musicfreaks'},
#  'TRMMGIB12903D043E5': {'artist': 'Luis Bacalov',
#   'title': 'The Color Of The Water / Dreaming Of The Future'},
#  'TRMMGKT12903CA6C1A': {'artist': 'AJP', 'title': 'Nothing More to Say'},
#  'TRMMGER128F9324C09': {'artist': 'La Souris Déglinguée',
#   'title': "Rock'n'roll vengeance"},
#  'TRMMGVE128F427B346': {'artist': 'Mickey 3D',
#   'title': 'Qui ? (version baba cool)'},
#  'TRMMGXC12903CB18F6': {'artist': 'Glen Glenn', 'title': 'Laurie Ann'},
#  'TRMMGRT128F93517C1': {'artist': 'Sofia Karlsson', 'title': 'Näckaspel'},
#  'TRMMGZH128F14AE4CF': {'artist': 'STEVE TAYLOR',
#   'title': "Whatcha Gonna Do When Your Number's Up?   (The Best We Could Find Album Version)"},
#  'TRMMGMB128F9321A3E': {'artist': 'Junkyard', 'title': 'Waste of Time'},
#  'TRMMHOK128F4273A4E': {'artist': 'JK', 'title': 'Deep in the night'},
#  'TRMMHGT128F42B91AD': {'artist': 'Teairra Marí',
#   'title': 'Make Her Feel Good'},
#  'TRMMHTC12903C9AF55': {'artist': 'Morrissey',
#   'title': 'Margaret On The Guillotine (LP Version)'},
#  'TRMMHBF12903CF6E59': {'artist': 'Laurel & Hardy',
#   'title': "At the Ball_ That's All"},
#  'TRMMHWI128F423B6AD': {'artist': 'Pestilence',
#   'title': 'Presence Of The Dead (Album Version)'},
#  'TRMMHDI128F42442F4': {'artist': 'Biffy Clyro',
#   'title': 'Love Has A Diameter'},
#  'TRMMHBW12903CAFDE7': {'artist': 'Mental Overdrive', 'title': 'Communion'},
#  'TRMMHRD128F4243970': {'artist': 'Exhumed', 'title': 'No quarter'},
#  'TRMMHIC128F92E8AE7': {'artist': 'Johnny Cash', 'title': 'Rowboat'},
#  'TRMMHAK128F42667CA': {'artist': 'Derek Trucks;Solomon Burke',
#   'title': 'Home In Your Heart'},
#  'TRMMHGC128F9338059': {'artist': 'New York Rel-X',
#   'title': 'Sold Out Of Love'},
#  'TRMMHYH128F4262566': {'artist': 'Sensations', 'title': "He's So Brave"},
#  'TRMMHEG128F42783F1': {'artist': 'Bad Dreams Fancy Dress',
#   'title': 'Rave Up'},
#  'TRMMHMD128F427428D': {'artist': 'Blue Foundation', 'title': '02.17 AM'},
#  'TRMMHAK128F4244179': {'artist': 'The Real Kids', 'title': "She's Alright"},
#  'TRMMHCQ128F92C9727': {'artist': 'Dora The Explorer',
#   'title': 'The Itsy Bitsy Spider'},
#  'TRMMHXD128F92E344B': {'artist': 'Billy Cobham', 'title': 'Mirage'},
#  'TRMMHKG128F425EBC4': {'artist': 'EM1', 'title': 'How Great Is Our King'},
#  'TRMMHGY128F42956EC': {'artist': 'Santa Claws and the Naughty But Nice Orchestra',
#   'title': 'Battery'},
#  'TRMMHKG12903CDB1B5': {'artist': 'Foals', 'title': 'Black Gold'},
#  'TRMMHRF128F424C910': {'artist': 'Lird Van Goles',
#   'title': "Walk In Holy Ghostwood/Time's Going On"},
#  'TRMMHVC128F92F2941': {'artist': 'Mississippi Sheiks',
#   'title': "When You're Sick With The Blues"},
#  'TRMMHFS128F93039A6': {'artist': 'Jessica Folcker',
#   'title': 'Snowflakes (VeebeeO Remix)'},
#  'TRMMHIG128F4228C77': {'artist': 'Visaci Zamek', 'title': 'Traktor'},
#  'TRMMHBL128F42BA0A8': {'artist': 'Bryn Christopher', 'title': "Smilin'"},
#  'TRMMHXQ12903CA60B8': {'artist': 'Voltio', 'title': 'Atrevida Bandolera'},
#  'TRMMHFO128F426E55C': {'artist': 'Hexstatic feat. Juice Aleem',
#   'title': 'Distorted Minds'},
#  'TRMMHND128F1479356': {'artist': 'Mediengruppe Telekommander',
#   'title': 'Trend / Sprengkörper (Medley) (Live)'},
#  'TRMMHEB128F930B953': {'artist': 'Middle Distance Runner',
#   'title': 'The Unbeliever'},
#  'TRMMHZK128F933648C': {'artist': 'Denison Witmer', 'title': 'Paper Doll'},
#  'TRMMHMD128F42915F1': {'artist': 'Boney M. 2000', 'title': 'Gotta Go Home'},
#  'TRMMHWM128F9316BD3': {'artist': 'Michael Stanley Band',
#   'title': 'Gypsy Eyes'},
#  'TRMMHFP128F935450F': {'artist': 'The Show is the Rainbow', 'title': 'Three'},
#  'TRMMHLC128F92D80ED': {'artist': 'Kill The Client', 'title': 'Gridlock'},
#  'TRMMHPJ12903CF3225': {'artist': 'Giant Drag', 'title': 'White Baby'},
#  'TRMMHDT128F422F115': {'artist': 'Thursday',
#   'title': 'A Hole In The World (Album Version)'},
#  'TRMMHAV128F427F9E8': {'artist': 'The Peelers',
#   'title': "That's Why I'm Leaving"},
#  'TRMMHMD12903CEC613': {'artist': 'Janie Fricke',
#   'title': "Your Heart's Not In It"},
#  'TRMMHMZ128F92F3424': {'artist': 'Johnny Ventura',
#   'title': 'La Inseminacion'},
#  'TRMMHSM128F42B0CB8': {'artist': 'Willie Barcena', 'title': 'Willie Barcena'},
#  'TRMMHKH128F92FD60E': {'artist': 'Miquel Brown',
#   'title': "This Time It's Real"},
#  'TRMMHXV128F930119C': {'artist': 'Davol', 'title': 'Final Promise (World)'},
#  'TRMMHUV128F424E0C3': {'artist': 'The Cult',
#   'title': 'Stand Alone (Album Version)'},
#  'TRMMHCS128F92E6CBC': {'artist': 'J. Tillman',
#   'title': 'If I Get to the Borderline'},
#  'TRMMHPF128F931BDD6': {'artist': 'Joshua Redman', 'title': 'Insomnomaniac'},
#  'TRMMHIT12903CFAF12': {'artist': 'Leonard Cohen',
#   'title': 'Tonight Will Be Fine'},
#  'TRMMHMJ128F423816F': {'artist': 'Linda Ronstadt',
#   'title': 'Straighten Up And Fly Right  (LP Version)'},
#  'TRMMHWD128F14AE65F': {'artist': 'Michael Card',
#   'title': 'Will You Not Listen?'},
#  'TRMMHGZ12903CD9677': {'artist': 'Floor',
#   'title': 'Kallisti \x13 Song For Eris'},
#  'TRMMHVN128F428E67E': {'artist': 'Falco', 'title': 'Zuviel Hitze'},
#  'TRMMCPK128F424A9DE': {'artist': "Lighnin' Hopkins", 'title': 'Bunion Blues'},
#  'TRMMCKH128F1494939': {'artist': 'Perturbazione', 'title': 'Se Fosse Adesso'},
#  'TRMMCTR128F145CE15': {'artist': 'Bobbi Humphrey',
#   'title': 'Please Set Me At Ease'},
#  'TRMMCGW128F422C4B9': {'artist': 'Angelus Apatrida',
#   'title': 'Killers And Killed'},
#  'TRMMCKG128F426E651': {'artist': 'Operator Please', 'title': 'Pantomime'},
#  'TRMMCJR128F42667B2': {'artist': 'Spencer Parker',
#   'title': 'Beautiful Noise'},
#  'TRMMCTJ128F933AE36': {'artist': 'Katie Melua',
#   'title': 'Nine Million Bicycles'},
#  'TRMMCBU128E0791823': {'artist': 'The Cranberries', 'title': 'Do You Know'},
#  'TRMMCFW128F4285276': {'artist': 'Juan Formell y los Van Van',
#   'title': 'La titimania'},
#  'TRMMCLY128F426B2EA': {'artist': 'Teenage Bad Girl', 'title': 'Vacuum'},
#  'TRMMCXU128F42A4DD1': {'artist': 'Scandinavian Music Group', 'title': 'Sä'},
#  'TRMMCNI128F42AC53B': {'artist': 'Martina McBride', 'title': 'You Win Again'},
#  'TRMMCDR128F423AB03': {'artist': 'Michael Cera & Ellen Page',
#   'title': 'Anyone Else But You'},
#  'TRMMCBB128EF34BE2D': {'artist': 'Scott Glasgow', 'title': 'Maia Sterling'},
#  'TRMMCJQ12903CD48A9': {'artist': 'Bone Thugs-N-Harmony',
#   'title': 'Wanna Be (Explicit Album Version)'},
#  'TRMMCNX12903CA35F7': {'artist': 'Lou Rhodes', 'title': 'The Rain'},
#  'TRMMCGY128F424E03F': {'artist': 'Elizabeth Daily', 'title': 'Shake It Up'},
#  'TRMMCYD128F92C7FDF': {'artist': 'Russ Taff', 'title': 'I Cry (LP Version)'},
#  'TRMMCWV128F424428E': {'artist': 'Peter Schilling & Boom-Bastic',
#   'title': "Major Tom '94(English Version)"},
#  'TRMMCFO128F426C420': {'artist': 'Brandy', 'title': 'Who I Am'},
#  'TRMMCAC128F9325E72': {'artist': 'Peter Van Hoesen',
#   'title': 'Strikethrough'},
#  'TRMMCHV128F427D29E': {'artist': 'Harper Simon', 'title': 'Henrieta'},
#  'TRMMCZK128F92F5288': {'artist': '3 Doors Down',
#   'title': 'Your Arms Feel Like Home'},
#  'TRMMCHN128E079507C': {'artist': 'Cornelis Vreeswijk',
#   'title': 'Telegram för en tennsoldat'},
#  'TRMMCCU128F92E1A71': {'artist': 'Brazilian Girls',
#   'title': 'Never Met A German'},
#  'TRMMCIE12903CC2DB0': {'artist': 'Career Suicide',
#   'title': 'Stones You Throw'},
#  'TRMMCDO128F146A75B': {'artist': 'Photek', 'title': 'Solaris'},
#  'TRMMCKM12903CF4808': {'artist': 'Gilberto Gil', 'title': 'Oriente'},
#  'TRMMCMA12903CDB675': {'artist': 'Robert Pollard',
#   'title': 'Perverted Eyelash'},
#  'TRMMCLY128F148C23F': {'artist': 'The Race', 'title': 'Eye Spy'},
#  'TRMMCYF128F421536F': {'artist': 'Marta Sanchez',
#   'title': 'Tiempo Al Tiempo'},
#  'TRMMCPH128F429F862': {'artist': 'Puddle Of Mudd', 'title': 'Out Of My Head'},
#  'TRMMCKW128F428E54C': {'artist': 'Raging Speedhorn',
#   'title': 'Knives and Faces'},
#  'TRMMCZF128F9339016': {'artist': 'Leonard Cohen', 'title': 'Suzanne'},
#  'TRMMCWE12903D02774': {'artist': 'Max Brannslokker', 'title': "Telze'"},
#  'TRMMCVW128F93401E3': {'artist': 'R.L. Burnside',
#   'title': "Don't Stop Honey (feat. Cedric Burnside)"},
#  'TRMMCTY128F9360E87': {'artist': 'Omar & The Howlers',
#   'title': "Girl's Got Rhythm"},
#  'TRMMCLO128F92ECA18': {'artist': 'Jane Monheit',
#   'title': 'I Do It For Your Love'},
#  'TRMMCQT128F9318823': {'artist': 'Bethany Dillon',
#   'title': 'All I Need (Key-Ab-Premiere Performance Plus)'},
#  'TRMMCAU128F9332597': {'artist': 'YGGDRASIL',
#   'title': 'Beyond the Borders of Sanity'},
#  'TRMMCRH12903CDE79B': {'artist': 'Popsicle', 'title': 'Blow Up'},
#  'TRMMCUQ128F92CA654': {'artist': 'Roosevelt Sykes',
#   'title': 'Music Is My Business'},
#  'TRMMRDO128F4233510': {'artist': 'Albert Cummings',
#   'title': 'Your Sweet Love'},
#  'TRMMRZW128EF34DF59': {'artist': 'The Chariot', 'title': 'Back To Back'},
#  'TRMMRIE128F92FB226': {'artist': 'M.I.K.E. vs. Andrew Bennett',
#   'title': 'A Better World'},
#  'TRMMRNI128EF34C4A7': {'artist': 'Elakelaiset', 'title': 'Humppakavalier'},
#  'TRMMRRC128F4278129': {'artist': 'Big John Greer',
#   'title': 'Clambake Boogie'},
#  'TRMMRJJ128F9319DE9': {'artist': 'Alejandro Fernandez', 'title': 'Júrame'},
#  'TRMMRXH128F14AE815': {'artist': 'Steve Green',
#   'title': 'We Trust In The Name Of The Lord Our God (Where Mercy Begins Album Version)'},
#  'TRMMRJG128F42A7B19': {'artist': 'Premiata Forneria Marconi',
#   'title': 'Chi Ha Paura Della Notte?'},
#  'TRMMRIO128F423DD33': {'artist': 'Mark Lanegan', 'title': 'Sunrise (Album)'},
#  'TRMMRFQ128F425A508': {'artist': 'The Marx Brothers',
#   'title': "Harpo's bazar"},
#  'TRMMRPV128F93110FE': {'artist': 'Nouvelle Vague', 'title': 'The American'},
#  'TRMMRJL128F92C48AB': {'artist': 'The White Tie Affair',
#   'title': 'The Letdown'},
#  'TRMMRIT128F4278B2C': {'artist': 'Carla Bozulich',
#   'title': "I Couldn't Believe It Was True"},
#  'TRMMRYK128F92EE6B7': {'artist': 'Stinking Lizaveta',
#   'title': 'A Man Without a Country'},
#  'TRMMRGC128F4277BFF': {'artist': '9 Shocks Terror', 'title': 'Sex'},
#  'TRMMRFI128F148ADDA': {'artist': 'Eastmountainsouth',
#   'title': 'Show Me The River'},
#  'TRMMRNL128F14AA221': {'artist': '24-7 Spyz', 'title': 'Fire & Water'},
#  'TRMMRYT128F42B228E': {'artist': 'Frenzal Rhomb',
#   'title': "You Can't Move Into My House"},
#  'TRMMRQQ12903CD4323': {'artist': 'Virus', 'title': 'Carheart'},
#  'TRMMRYN12903CF2E58': {'artist': 'Swat-Squad', 'title': 'Oxygen'},
#  'TRMMRUH128F92E9CA8': {'artist': 'Venice is Sinking', 'title': 'Andropolis'},
#  'TRMMRCX128F933DB3B': {'artist': 'The Oscar Peterson Trio',
#   'title': 'The Things We Did Last Summer'},
#  'TRMMREE128F425C8FD': {'artist': 'Takana Zion', 'title': 'Conakry'},
#  'TRMMRVE128E0796429': {'artist': 'Breite Seite', 'title': 'Kein Wort'},
#  'TRMMROM12903CB6FD4': {'artist': 'Cab Calloway',
#   'title': 'Jonah Joins The Cab'},
#  'TRMMRWO128F92F8A4C': {'artist': 'Fetterline', 'title': 'Scarlet Winter'},
#  'TRMMRBW128F4284BDB': {'artist': 'DJ Quik', 'title': "Quik's Groove VII"},
#  'TRMMRZS128F9316283': {'artist': 'Alberto Fortis', 'title': "L'Uomo Grande"},
#  'TRMMRZQ128F14A4E44': {'artist': 'Penguin Café Orchestra',
#   'title': 'Telephone And Rubber Band (Live) (2001 Digital Remaster)'},
#  'TRMMRRA12903CBE801': {'artist': 'J-Kwon',
#   'title': 'Ghetto (feat. Gino Green)'},
#  'TRMMRXG128F424865E': {'artist': 'The Answering Machine',
#   'title': 'Decadent'},
#  'TRMMRWX12903CF4DF1': {'artist': 'The Wonder Years',
#   'title': 'Everything I Own Fits In This Backpack'},
#  'TRMMRUF128F427A25F': {'artist': 'Piccola Bottega Baltazar',
#   'title': 'Gli Amanti Di Val Morel'},
#  'TRMMRVL128F92F6767': {'artist': 'Rhian Sheehan', 'title': 'Cosmology'},
#  'TRMMRKO128F92F2B84': {'artist': 'Anti Nowhere League', 'title': 'Am I Dead'},
#  'TRMMRFV128F931E054': {'artist': 'Mutabor', 'title': 'schmetterlinge'},
#  'TRMMRRP128F427CC01': {'artist': 'Fito Paez', 'title': 'Tres Agujas'},
#  'TRMMRHG12903CC6BE2': {'artist': 'Yma Sumac',
#   'title': 'Ataypura (High Andes)'},
#  'TRMMRGF128F4263395': {'artist': 'Pony Club', 'title': 'Single'},
#  'TRMMRJD128F42756E5': {'artist': 'Sunbeam', 'title': 'Outside World'},
#  'TRMMRUB12903CA097C': {'artist': 'Brook Benton', 'title': 'Lie To Me'},
#  'TRMMRJO128F933C229': {'artist': 'Les Wriggles', 'title': 'Dieubouddhallah'},
#  'TRMMRAC128F4238209': {'artist': 'Josh Turner',
#   'title': 'The Way He Was Raised'},
#  'TRMMRCO128F42705EB': {'artist': 'Mouse On Mars', 'title': 'Subnubus'},
#  'TRMMRGB128F92EBE23': {'artist': 'Crash Parallel',
#   'title': 'Long Night Dreaming'},
#  'TRMMREB12903CEB1B1': {'artist': 'Slim Harpo',
#   'title': 'I Got Love If You Want It'},
#  'TRMMRMK128F92DF44D': {'artist': 'Glissade', 'title': 'Burned in Blue'},
#  'TRMMBSC128F42B9B21': {'artist': 'Akcent', 'title': 'Feel Me'},
#  'TRMMBSC128F9342FBA': {'artist': 'Claire Hamill', 'title': 'Denmark'},
#  'TRMMBCM128F423BB90': {'artist': 'Madredeus', 'title': 'O Sonho'},
#  'TRMMBDC128F4292DA9': {'artist': 'Boyd Tinsley', 'title': 'Perfect World'},
#  'TRMMBDE128F932F640': {'artist': 'Blink-182', 'title': 'Boring'},
#  'TRMMBJW12903CB2C57': {'artist': 'Trader Horne', 'title': 'Velvet To Atone'},
#  'TRMMBHK128F427CC41': {'artist': 'David Lanz',
#   'title': 'Escapades Of Pan (Orchestral Version)'},
#  'TRMMBOK128E07999DD': {'artist': 'Ms. Dynamite', 'title': 'Gotta Let It Go'},
#  'TRMMBVA12903CFB9E0': {'artist': 'Peter Broderick',
#   'title': 'Part 5: Awaken/Panic/Restraint'},
#  'TRMMBDB12903CE37DB': {'artist': 'Richard Berry',
#   'title': 'Yama Yama Pretty Mama (Digitally Remastered)'},
#  'TRMMBHY128EF34FE6A': {'artist': 'Billy J. Kramer', 'title': 'From A Window'},
#  'TRMMBZT128F9329034': {'artist': 'The Count Bishops',
#   'title': 'Down The Road Apiece'},
#  'TRMMBIO128F4262553': {'artist': 'Union 13',
#   'title': 'A Short Supply (of Truth)'},
#  'TRMMBVF128F932AD4B': {'artist': 'Helix', 'title': 'Animal House'},
#  'TRMMBAR128F4274AE3': {'artist': 'Afu-Ra', 'title': 'Power Skit #2'},
#  'TRMMBRU128F9310F18': {'artist': 'I Concur', 'title': 'Oblige'},
#  'TRMMBEI128F422A590': {'artist': 'Nação Zumbi', 'title': 'Voyager'},
#  'TRMMBNU12903CA3813': {'artist': 'Lou Rhodes', 'title': 'This Love'},
#  'TRMMBWS128F42787ED': {'artist': 'End Of Fashion', 'title': 'Hardcore'},
#  'TRMMBCH128F92F9A94': {'artist': 'Cliff Richard',
#   'title': 'Somewhere Along The Way (Mono) (1998 Digital Remaster)'},
#  'TRMMBXD128F1477148': {'artist': 'Dashboard Confessional',
#   'title': 'Morning Calls'},
#  'TRMMBGI128F92D19C4': {'artist': 'Lewis Taylor', 'title': 'Track'},
#  'TRMMBCD128F429AA45': {'artist': 'Middle Of The Road',
#   'title': 'Give It Time'},
#  'TRMMBSH128F424A4ED': {'artist': 'Robert Hood', 'title': 'The Body Human'},
#  'TRMMBBL128F146722B': {'artist': 'June Christy',
#   'title': '(It Will Have To Do) Until The Real Thing Comes Along (1995 Digital Remaster)'},
#  'TRMMBQC128F934B56B': {'artist': 'Tristan Garner', 'title': 'Give Love'},
#  'TRMMBBF128F931C337': {'artist': 'Black Sabbath', 'title': 'Wishing Well'},
#  'TRMMBMI128F421A4C2': {'artist': 'Roger Creager',
#   'title': "What's A Lonely Girl To Do"},
#  'TRMMBQL128F42620F8': {'artist': 'Bodies Of Water',
#   'title': 'It Is Familiar'},
#  'TRMMBIO12903CBBE27': {'artist': 'Dino Merlin', 'title': 'Zid'},
#  'TRMMBTA12903CF1FB6': {'artist': 'Stampin´ Ground',
#   'title': 'Bear The Scars'},
#  'TRMMBWO128F4244A67': {'artist': 'Luka Bloom', 'title': 'Gypsy Music'},
#  'TRMMBTX12903C9C04A': {'artist': 'Sebkha-Chott', 'title': 'All Blacks'},
#  'TRMMBGI128E0788B31': {'artist': 'Air',
#   'title': 'Casanova 70 The Secret Of Cool'},
#  'TRMMBDK128F425F699': {'artist': 'Tiny Masters Of Today',
#   'title': 'Hey Mr. DJ (XFM Session)'},
#  'TRMMBOZ128F1470286': {'artist': 'MALIAN MUSICIANS & DAMON ALBARN',
#   'title': 'Sunset Coming On'},
#  'TRMMBUX128F930B141': {'artist': 'Neikka RPM',
#   'title': 'I Am Your Girl (love is blue remix by A.T:F)'},
#  'TRMMBAH128F92C2934': {'artist': 'Entombed', 'title': 'Year One Now'},
#  'TRMMBPI128F14A48E6': {'artist': 'Down To The Bone',
#   'title': 'Electra Glide'},
#  'TRMMBQZ12903CF0F9A': {'artist': 'No Age', 'title': 'Genie'},
#  'TRMMBZW128F148BDA4': {'artist': 'Samantha Mumba',
#   'title': "What's It Gonna Be"},
#  'TRMMBOC12903CEB46E': {'artist': 'Marcus Worgull',
#   'title': 'Drumstern (BONUS TRACK)'},
#  'TRMMBRN128F4256A56': {'artist': 'Deadsoil', 'title': 'The Promise'},
#  'TRMMBIY128F149F02C': {'artist': 'The Undisputed Truth', 'title': 'Poontang'},
#  'TRMMBMP12903CDCE45': {'artist': 'Johnny & the Hurricanes',
#   'title': 'Buckeye'},
#  'TRMMBHE12903CFF29C': {'artist': 'Rumble Pack', 'title': 'Back to Basics'},
#  'TRMMFCR128F147F293': {'artist': 'Jealousy', 'title': 'Lucy'},
#  'TRMMFJW128F149EF7F': {'artist': 'The Temptations',
#   'title': "I'm Glad There Is You"},
#  'TRMMFEX128F92FC4F4': {'artist': 'Roger Daltrey',
#   'title': 'Would A Stranger Do?'},
#  'TRMMFNT128F146AB95': {'artist': 'Bebe Winans', 'title': 'Thank You'},
#  'TRMMFRZ128F9331C09': {'artist': 'Richard Galliano', 'title': 'Giselle'},
#  'TRMMFSL128F4234583': {'artist': 'Kanye West / Mos Def',
#   'title': 'Drunk and Hot Girls'},
#  'TRMMFUB128F425E857': {'artist': 'Senore Matze Rossi',
#   'title': 'Ich Lasse Mir Nichts Mehr Nehmen'},
#  'TRMMFKN128F931775E': {'artist': 'Twenty 4 Seven', 'title': 'Good Times'},
#  'TRMMFHU128F92D7E48': {'artist': 'Mandisa',
#   'title': 'Children Go Where I Send Thee'},
#  'TRMMFQZ128F92F56FC': {'artist': 'Flux of Pink Indians',
#   'title': 'Background Of Malfunction'},
#  'TRMMFTD128F14A23A6': {'artist': 'Boss Volenti', 'title': 'The Gun'},
#  'TRMMFAR128F42986F7': {'artist': 'Operation Ivy', 'title': 'Knowledge'},
#  'TRMMFKY128F423A78F': {'artist': 'Padded Cell', 'title': 'Savage Skulls'},
#  'TRMMFQU128F9342A64': {'artist': 'Inhume', 'title': 'Fucked with paranoia'},
#  'TRMMFVV128F426A658': {'artist': 'Saxon',
#   'title': '747 (Strangers In The Night) (Live At The Hammersmith Odeon) (1997 Digital Remaster)'},
#  'TRMMFFA12903CE7323': {'artist': 'Judy Mowatt', 'title': 'Think'},
#  'TRMMFJS128F93428C7': {'artist': 'Commit Suicide', 'title': 'Ablation'},
#  'TRMMFIS128E078EDEA': {'artist': 'Aerosmith', 'title': "Cryin'"},
#  'TRMMFYF128F421EFDE': {'artist': 'Ricaine', 'title': '308'},
#  'TRMMFIG128F1464EDA': {'artist': 'Erasure', 'title': 'Victim Of Love'},
#  'TRMMFAF128F933C3C9': {'artist': 'Lio', 'title': 'Je me tords'},
#  'TRMMFZM12903CBD45C': {'artist': 'Ubar Tmar',
#   'title': 'When The Light Is Gone live mix'},
#  'TRMMFMZ128F93302C0': {'artist': 'FFH', 'title': 'Through My Eyes'},
#  'TRMMFVZ128F92FE11F': {'artist': 'The Spektrum', 'title': 'Nenphilis'},
#  'TRMMFRN128F92E5FEF': {'artist': 'The Hoosiers', 'title': 'Cops And Robbers'},
#  'TRMMFXR12903CF4536': {'artist': 'Paradise Lost', 'title': 'Intro'},
#  'TRMMFXM128F424295C': {'artist': 'Topmodelz', 'title': 'Something About You'},
#  'TRMMFIU128F42357BF': {'artist': 'Good Riddance',
#   'title': "Yesterday's Headlines"},
#  'TRMMFIR128F4221C4F': {'artist': 'Kaya Project',
#   'title': 'Stone Turns Black'},
#  'TRMMFLA128F425C1C0': {'artist': 'The Last Dance',
#   'title': 'Wake Me Screaming'},
#  'TRMMFEH128F424B406': {'artist': 'The Exies', 'title': '1970'},
#  'TRMMFHL128F146E5ED': {'artist': 'Nerina Pallot',
#   'title': 'Nickindia (remastered)'},
#  'TRMMQPE128F423A34E': {'artist': 'Happy Mondays',
#   'title': 'Moving In With (Re-mastered version)'},
#  'TRMMQTK128F42729AC': {'artist': 'Jerry Ropero Featuring Cozi',
#   'title': 'The Storm (John Dahlback Remix) (Feat. Cozi)'},
#  'TRMMQMP128F423A7E3': {'artist': 'Jenniffer Kae', 'title': 'Ebb And Flow'},
#  'TRMMQFO128F14A214E': {'artist': 'Claw Boys Claw', 'title': 'Bones'},
#  'TRMMQJH128F1464A57': {'artist': 'Liam Lynch', 'title': 'Happy'},
#  'TRMMQZZ128F4249F40': {'artist': 'Minnesota Orchestra',
#   'title': 'Danse Macabre'},
#  'TRMMQOV128F4272A48': {'artist': 'The Wailers', 'title': 'No Sympathy'},
#  'TRMMQPD128F92F6AFD': {'artist': 'DJ Remy', 'title': 'Till Ya Drop! 2007'},
#  'TRMMQAN128F4286DFA': {'artist': 'Arnaldo Antunes',
#   'title': 'Eu Não Sou Da Sua Rua'},
#  'TRMMQFA128F4281BAC': {'artist': 'Kari Tapio', 'title': 'Tom Dooley'},
#  'TRMMQKR12903CD5675': {'artist': 'Attack', 'title': 'Två av Oss'},
#  'TRMMQEM12903CB415B': {'artist': '220 Volt',
#   'title': 'Woman In White (LIVE)'},
#  'TRMMQRB12903CA3738': {'artist': 'Slowpho', 'title': 'Devoted'},
#  'TRMMQGS128F423CA04': {'artist': 'Jaco Pastorius Big Band',
#   'title': 'Amerika (Live Verison)'},
#  'TRMMQSP128F1486267': {'artist': 'Story Of The Year',
#   'title': 'Until The Day I Die (Album Version)'},
#  'TRMMQYP128F428E72A': {'artist': 'The Untouchables', 'title': 'Shine On'},
#  'TRMMQVN128F4262999': {'artist': 'Joe Satriani',
#   'title': "Rubina's Blue Sky Of Happiness"},
#  'TRMMQPT12903CBFF20': {'artist': 'Emerson_ Lake & Palmer',
#   'title': 'Still...You Turn Me On'},
#  'TRMMQQR12903D033B4': {'artist': 'Los Compadres',
#   'title': 'Los barrios de Santiago'},
#  'TRMMQUB128F42893CA': {'artist': 'Steve Cropper & Felix Cavaliere',
#   'title': 'Love Appetite'},
#  'TRMMQNL128F933A7FB': {'artist': 'Årabrot', 'title': 'I'},
#  'TRMMQDL128F424272B': {'artist': 'Ambrosia',
#   'title': "Holdin' On To Yesterday"},
#  'TRMMQPR128F9330C05': {'artist': 'I Walk The Line',
#   'title': 'The Man Without A Name'},
#  'TRMMQQT12903CB44E8': {'artist': 'Ed McCurdy',
#   'title': 'The Playhouse Saint'},
#  'TRMMQMT128F148AACB': {'artist': 'Grand Ulena',
#   'title': 'Between Tholozan And Oleatha'},
#  'TRMMQAX128F9334E48': {'artist': 'Crosby_ Stills & Nash',
#   'title': 'House Of Broken Dreams'},
#  'TRMMQUO128F92EFDA8': {'artist': 'Shit and Shine', 'title': 'Nuns Leg'},
#  'TRMMQDK128F4266EBF': {'artist': 'Megalon', 'title': 'Sons Of Sarah Connors'},
#  'TRMMQPM128F4266029': {'artist': 'Cobra Starship',
#   'title': 'My Moves Are White [White Hot_ That Is] (Album Version)'},
#  'TRMMQQP128F429096F': {'artist': 'Cabballero', 'title': 'Hymn'},
#  'TRMMQOL128F9340687': {'artist': 'Paramore', 'title': 'Rewind (Demo)'},
#  'TRMMQFP128F92F0413': {'artist': 'System of a Down',
#   'title': "This Cocaine Makes Me Feel Like I'm On This Song"},
#  'TRMMQWC128F4233674': {'artist': 'Josh Pyke', 'title': 'Sew My Name'},
#  'TRMMQMY128F930BD2F': {'artist': 'Barry Brown',
#   'title': 'Give Thanks and Praise - Original'},
#  'TRMMQQU128EF3583ED': {'artist': 'Williamson',
#   'title': 'Sailing To The Botton'},
#  'TRMMQUQ128F4261E3A': {'artist': 'The Dickey Betts Band',
#   'title': "The Blues Ain't Nothin'"},
#  'TRMMQME12903CD2B9D': {'artist': 'Naked Raygun', 'title': 'Entrapment'},
#  'TRMMQCW128F930E26F': {'artist': 'Kaizers Orchestra',
#   'title': 'Kaizers 115. Drøm'},
#  'TRMMQUA128F425761E': {'artist': 'Wesley Willis', 'title': 'Jesus Christ'},
#  'TRMMQXZ128F92D0A0E': {'artist': 'Manjul', 'title': 'Hungry Belly'},
#  'TRMMZRE128F42B799E': {'artist': 'Daniel Balavoine',
#   'title': "Sauver L'Amour"},
#  'TRMMZJO128F42434B2': {'artist': 'Sandhy SonDoro',
#   'title': 'Don´t Let It Bring You Down'},
#  'TRMMZSA128F4233C55': {'artist': 'Willie "Big Eyes" Smith',
#   'title': 'Tell Me Mama'},
#  'TRMMZSX128F4285EEC': {'artist': 'Planlos', 'title': 'Rock-Legenden'},
#  'TRMMZZF128F92F96E1': {'artist': 'Boozoo Bajou', 'title': 'Fuersattel'},
#  'TRMMZAW128F930B851': {'artist': 'Not Your Average Hippy',
#   'title': 'Thirteen'},
#  'TRMMZMW128F427C396': {'artist': 'Dreams Come True', 'title': 'Moonlight'},
#  'TRMMZNK128F149044A': {'artist': 'Talk Talk',
#   'title': 'I Believe In You (1997 Digital Remaster)'},
#  'TRMMZFP128F934E711': {'artist': 'Dominik Eulberg', 'title': 'Ambivalent'},
#  'TRMMZSB128F14A4950': {'artist': 'The Rutles',
#   'title': "Major Happy's Up And Coming Once Upon A Good Time Band"},
#  'TRMMZEY128F4244253': {'artist': 'Half Japanese', 'title': "Movin' On Up"},
#  'TRMMZNV128F9352E7A': {'artist': 'Fragile State',
#   'title': 'Undercurrent (Alucidnation Downtempo Mix)'},
#  'TRMMZQE128F92E799D': {'artist': 'John Coltrane Quartet',
#   'title': 'I Wish I Knew'},
#  'TRMMZMG128F427CA28': {'artist': 'Jeff Lorber', 'title': "Uncle Darrow's"},
#  'TRMMZJI12903CA126D': {'artist': 'Microwave Dave and the Nukes',
#   'title': 'Body And Fender Man'},
#  'TRMMZNN128F42887EF': {'artist': 'Why?', 'title': 'Gemini (Birthday Song)'},
#  'TRMMZIM12903CBBF55': {'artist': 'Eric Sneo', 'title': 'Coming Home'},
#  'TRMMZFT128F4252625': {'artist': 'AGATHODAIMON', 'title': 'After dark'},
#  'TRMMZTO128F92C95BD': {'artist': 'Bratri Ebenove', 'title': 'Karlovy Vary'},
#  'TRMMZLZ128F421774B': {'artist': 'Halfway to Gone',
#   'title': "Never Comin' Home"},
#  'TRMMZCO128F4220E1F': {'artist': 'Chiasm', 'title': 'Rewind'},
#  'TRMMZDO128F426B386': {'artist': 'Los Enemigos', 'title': 'Nadie Me quiere'},
#  'TRMMZYE128F9349941': {'artist': 'La Habitacion Roja',
#   'title': 'Cuando Te Hablen De Mi'},
#  'TRMMZXU128F427D16E': {'artist': 'Patent Pending', 'title': 'Job'},
#  'TRMMZRY128F426C014': {'artist': 'Kate Smith', 'title': 'Somebody Loves Me'},
#  'TRMMZFU128F42BCDCD': {'artist': 'Furry Lewis',
#   'title': 'Take Your Time Rag'},
#  'TRMMZTZ128F426365D': {'artist': 'Halo Of Flies', 'title': 'D.D.T. Fin 13'},
#  'TRMMZHL128F42677F0': {'artist': 'Shooting At Unarmed Men',
#   'title': 'Sailing Keeps You Safe'},
#  'TRMMZYR128F9305C1B': {'artist': 'Rabbit', 'title': 'Broken Arrows'},
#  'TRMMZXX128F146E474': {'artist': 'Curtis Stigers',
#   'title': "I Can't Stand Losing You"},
#  'TRMMZHD128F427FE98': {'artist': 'Devotchka',
#   'title': 'The Clockwise Witness'},
#  'TRMMZZD128F422AA3C': {'artist': 'Lacuna',
#   'title': 'Celebrate the Summer 2006'},
#  'TRMMZRL128F4238A3A': {'artist': 'Haikara', 'title': 'Jälleen on meidän'},
#  'TRMMZTM12903CD177A': {'artist': 'Bullet',
#   'title': "Ain't Got Time To Waste"},
#  'TRMMZCP128F14AFDA4': {'artist': 'Kreidler', 'title': 'Circles'},
#  'TRMMZTK12903D114FF': {'artist': 'Heredeiros Da Crus',
#   'title': 'Cocha Meu Minino'},
#  'TRMMZKO128F424AE86': {'artist': 'Carey Bell',
#   'title': 'Going Back To Louisiana'},
#  'TRMMZHG128F421B133': {'artist': 'Bill Perry', 'title': 'Big  Ass Green Van'},
#  'TRMMZQW128F9342C09': {'artist': 'Watchmaker', 'title': 'Jesus Is Coming'},
#  'TRMMZWQ128F93462CD': {'artist': 'Bob Baldwin', 'title': 'Cafezinho'},
#  'TRMMZKU128F4296801': {'artist': 'Rick Astley', 'title': 'Never Knew Love'},
#  'TRMMZOA128F147D074': {'artist': 'Bobbie Gentry',
#   'title': 'Mississippi Delta'},
#  'TRMMZRY12903D1368F': {'artist': 'Patrik Isaksson', 'title': 'Vågorna'},
#  'TRMMZOT128F149E9EE': {'artist': 'The Chantels', 'title': 'Prayee'},
#  'TRMMZNT128F4237C33': {'artist': 'David Sanborn',
#   'title': 'Hideaway (Album Version)'},
#  'TRMMZLQ12903CD7EA7': {'artist': 'Kurt Vile', 'title': 'Red Apples'},
#  'TRMMZAE128F930C07D': {'artist': 'A.C.T', 'title': 'Lord Of Lies'},
#  'TRMMZAC12903CEFFA5': {'artist': 'Impact', 'title': 'La Mosca'},
#  'TRMMIBQ128F92FAE23': {'artist': 'Conjunto Clasico', 'title': 'Malancolo'},
#  'TRMMIDH12903CC2667': {'artist': 'Billy Boy Arnold', 'title': 'Just a Dream'},
#  'TRMMIWS12903CDFDAD': {'artist': 'Asia 2001', 'title': 'Antartica'},
#  'TRMMIFX128F933BB35': {'artist': 'Gloria Lasso', 'title': 'Venus'},
#  'TRMMIFE128F1491C8E': {'artist': 'Robert Plant',
#   'title': 'Your Ma Said You Cried In Your Sleep Last Night  (2006 Remastered LP Version)'},
#  'TRMMIJB12903CD3A89': {'artist': 'DJ Fait', 'title': 'No Easy Way Out'},
#  'TRMMIDR128F1456A40': {'artist': 'Muddy Waters', 'title': 'All Night Long'},
#  'TRMMILX128F92FE3F7': {'artist': 'Senser', 'title': 'Sandhurst In Zero G'},
#  'TRMMIOJ128F92F40B9': {'artist': 'Iron Butterfly',
#   'title': 'Iron Butterfly Theme'},
#  'TRMMIAO128F9328C36': {'artist': 'DD/MM/YYYY', 'title': 'Cancerboy on Hash'},
#  'TRMMICT128F4287ABE': {'artist': 'Miracle Chosuke', 'title': 'Vallejo'},
#  'TRMMIYB12903CEFF1A': {'artist': 'The Jackson Southernaires',
#   'title': "It's A Blessing"},
#  'TRMMIPY128F423739E': {'artist': 'Mando Diao',
#   'title': 'Never Seen The Light Of Day (Radio Edit)'},
#  'TRMMIAR128F427AF13': {'artist': 'One Way System',
#   'title': 'Believe Yourself (Album Version)'},
#  'TRMMIHW128F9325496': {'artist': 'C-Block', 'title': 'First Love'},
#  'TRMMIIS128F426155F': {'artist': 'Benassi Bros. Feat. Dhany',
#   'title': 'Make Me Feel'},
#  'TRMMIEG128F425A851': {'artist': 'Tihuana', 'title': 'Como Eu Queria'},
#  'TRMMIAQ128F14802D5': {'artist': 'Andres Calamaro',
#   'title': 'La Verdadera Libertad'},
#  'TRMMIMB128F92F6356': {'artist': 'Los Amantes De Lola',
#   'title': 'Valiums A Tu Tia'},
#  'TRMMILJ128F4242AD2': {'artist': 'Incantation', 'title': 'Merciless tyranny'},
#  'TRMMIGK128F145893F': {'artist': 'Japan', 'title': 'The Art Of Parties'},
#  'TRMMIZZ128F4289298': {'artist': 'Bitty McLean',
#   'title': "It Keep Rainin' (Tears From My Eyes) (Radio Edit)"},
#  'TRMMIMZ128F9333503': {'artist': 'Continental Drifters',
#   'title': "Tomorrow's Gonna Be"},
#  'TRMMIHU12903CFF742': {'artist': 'Enchant', 'title': 'Invisible'},
#  'TRMMIUB128F428565E': {'artist': 'AfroReggae', 'title': 'Benedito'},
#  'TRMMIFD128F9325433': {'artist': 'DC Talk',
#   'title': "I Wish We'd All Been Ready (Key-Ab-Premiere Performance Plus)"},
#  'TRMMIMB128F93294FA': {'artist': 'Kokolo', 'title': 'Soul Power'},
#  'TRMMIAN128EF3671BA': {'artist': 'The Adverts', 'title': 'New Boys'},
#  'TRMMIDO128F1463A4E': {'artist': 'The Dickies', 'title': 'Fan Mail'},
#  'TRMMIIV128F14A2BC7': {'artist': 'O Rappa', 'title': 'Linha Vermelha'},
#  'TRMMIQH12903CC6652': {'artist': 'Clint Eastwood', 'title': 'Rowdy'},
#  'TRMMITS12903C9D127': {'artist': 'Natalino Otto',
#   'title': "Mamma Voglio Anch'io La Fidanzata"},
#  'TRMMISS128F932F24D': {'artist': 'Nessbeal', 'title': 'Rimes Instinctives'},
#  'TRMMIXP128F934674D': {'artist': 'Feadz', 'title': 'Liisborg Error'},
#  'TRMMIXE128F146C649': {'artist': 'No Innocent Victim',
#   'title': 'C.e.b. (Album Version)'},
#  'TRMMICW128F14548B8': {'artist': 'Yabby You', 'title': 'Warn Them Jah Dub'},
#  'TRMMIVM128F42326B9': {'artist': 'James Newton Howard/The Postman Soundtrack',
#   'title': 'Shelter In The Storm (Album Version)'},
#  'TRMMIUT128F932DE69': {'artist': 'Daniel Merriweather',
#   'title': "You Don't Know What Love Is (You Just Do As You're Told)"},
#  'TRMMIQN128F426B586': {'artist': 'Exile', 'title': 'Take Me To The River'},
#  'TRMMIKV128F4276904': {'artist': 'Bernard Harris', 'title': 'Let it Go'},
#  'TRMMIFK12903CE6B10': {'artist': "Chad Smith's Bombastic Meatbats",
#   'title': 'Into The Floyd'},
#  'TRMMALI12903CC8A96': {'artist': 'Sunlightsquare',
#   'title': 'I Believe In Miracles'},
#  'TRMMAFC128F93566B2': {'artist': 'Bill Perry', 'title': 'Honey Pie'},
#  'TRMMAVK128F92DF22F': {'artist': 'Verdena', 'title': 'Elefante'},
#  'TRMMAUM128F92D14F3': {'artist': 'Count Basie Big Band',
#   'title': 'Bookie Blues'},
#  'TRMMAWA128F4263E08': {'artist': 'The Bluetones', 'title': 'Mudslide'},
#  'TRMMAPV128F4272C35': {'artist': 'The Durutti Column',
#   'title': 'Sketch For Dawn (Live 13.8.1981)'},
#  'TRMMAWJ128F92EB125': {'artist': 'Gino Paoli',
#   'title': "Io Vado Con L'Anima"},
#  'TRMMAYA128F42A884A': {'artist': 'Aural Float', 'title': 'New Frontiers'},
#  'TRMMAMS128F92F3BAC': {'artist': 'Heston', 'title': 'Like Sunshine'},
#  'TRMMAMM12903CAF37A': {'artist': 'Shakespears Sister',
#   'title': "It's A Trip (Stems Mix)"},
#  'TRMMAOJ128F4243312': {'artist': 'Platero Y Tu',
#   'title': 'Un Abecedario Sin Letras'},
#  'TRMMAAZ128F427330F': {'artist': 'Section 25',
#   'title': 'Dirty Disco II (Pre-Mix version)'},
#  'TRMMAYV12903CBF158': {'artist': 'April March', 'title': 'Attention Cherie'},
#  'TRMMAWB128F4278517': {'artist': 'Life Of Agony',
#   'title': "Don't You (Forget About Me) (Album Version)"},
#  'TRMMABI12903CF5E42': {'artist': 'Adema', 'title': 'Until Now'},
#  'TRMMABF128F425862B': {'artist': 'Four Year Strong',
#   'title': 'Heroes Get Remembered_ Legends Never Die'},
#  'TRMMAVX128F9333866': {'artist': 'Mala Reputación', 'title': 'Abre los ojos'},
#  'TRMMAOE128F92E132F': {'artist': "Lightnin' Hopkins",
#   'title': 'Everyday I Have The Blues'},
#  'TRMMABQ128F92EADF9': {'artist': 'George Winston', 'title': 'Tamarack Pines'},
#  'TRMMALK128F4262C40': {'artist': 'Beady Belle',
#   'title': 'A Touch Of Paradise'},
#  'TRMMASU12903C9A2A4': {'artist': 'Hot Lips Page',
#   'title': "He's Pulling His Whiskers On"},
#  'TRMMAKR128F423A02B': {'artist': 'Anthony Cruz',
#   'title': "I've Been Waiting"},
#  'TRMMAGG128F4295B80': {'artist': 'Terry Stafford',
#   'title': 'She Wishes I Were You'},
#  'TRMMATM128F933D5F5': {'artist': 'Loquillo',
#   'title': 'Cadillac Solitario (Rockdelux Experience 23/11/04)'},
#  'TRMMALW128F92FD049': {'artist': 'John Mayer', 'title': 'Out Of My Mind'},
#  'TRMMAZT12903CF5EE5': {'artist': 'Evile', 'title': 'Thrasher'},
#  'TRMMAHM128F92E704F': {'artist': 'Mae Moore', 'title': "All I Can't Explain"},
#  'TRMMABD128F421F3DF': {'artist': 'HEATHEN', 'title': 'EYE OF THE STORM'},
#  'TRMMAIV128F92E7F55': {'artist': 'Eagles Of Death Metal',
#   'title': 'Already Died'},
#  'TRMMATD128F932C32B': {'artist': 'Casiotone For The Painfully Alone',
#   'title': 'You Were Alone'},
#  'TRMMARP128F4285872': {'artist': 'Gui Boratto',
#   'title': 'Like You (Supermayer Mix)'},
#  'TRMMABJ128F9339932': {'artist': 'Mick Clarke', 'title': 'Save The World'},
#  'TRMMAPG128F14831C9': {'artist': 'Obk',
#   'title': 'La Princesa De Mis Sueños (Octeto Versión)'},
#  'TRMMAPF128F4247CF1': {'artist': 'H.e.a.t', 'title': 'Intro'},
#  'TRMMAWT128EF36143B': {'artist': 'Andy Stochansky', 'title': 'Talk Show'},
#  'TRMMARQ128F92CC60D': {'artist': 'Hadag Nahash',
#   'title': 'California (Live)'},
#  'TRMMAAP128F146854E': {'artist': 'The Durutti Column',
#   'title': 'Tomorrow (Live Version)'},
#  'TRMMAWC128F4298163': {'artist': 'Pat Benatar', 'title': 'Little Paradise'},
#  'TRMMAPG128F428B247': {'artist': 'Bastian', 'title': 'Push the Right Knob'},
#  'TRMMAZS128F149F12B': {'artist': 'A Life Once Lost',
#   'title': 'The Change Came Suddenly'},
#  'TRMMAST128F9300AAB': {'artist': 'Lispector', 'title': 'Palace Of My Soul'},
#  'TRMMALU128F4257A0E': {'artist': 'Jorge Ben', 'title': 'Tim Dom Dom'},
#  'TRMMAVF128F147E239': {'artist': 'Marvin Gaye', 'title': 'Love For Sale'},
#  'TRMMAEY128F42675B0': {'artist': 'Sun Eats Hours', 'title': 'The Level'},
#  'TRMMAXK128F93122EF': {'artist': 'Verdena', 'title': 'La tua fretta'},
#  'TRMMAUP128F1489924': {'artist': 'Anti-Pasti', 'title': 'East To West'},
#  'TRMMANJ128F4271619': {'artist': 'Kimmo Liskomäen Pitkät Kalsarit',
#   'title': 'Luodinkestävä poikaystävä'},
#  'TRMMAPP128F92E6E8A': {'artist': 'Malkit Singh', 'title': 'Naa Puchna'},
#  'TRMMAYP128F933C018': {'artist': 'Rusted Root',
#   'title': 'Send Me On My Way (Album Version)'},
#  'TRMMAJX12903CCE253': {'artist': 'Jimmy Nail', 'title': 'W.L.T.M.'},
#  'TRMMAGK128F1497654': {'artist': 'Leif Ove Andsnes',
#   'title': 'Nordlandsbilleder (Pictures from Nordland) Suite No. 1 Op. 5: I.       Kvinneprofill (Portrait of a woman)'},
#  'TRMMATA128F934B2B1': {'artist': 'UFO',
#   'title': "No Place To Run (Live In Hammersmith 'BBC In Concert')"},
#  'TRMMANP128F1479293': {'artist': 'Timi Yuro', 'title': "Don't Blame Me"},
#  'TRMMAYZ128F429ECE6': {'artist': 'I Ribelli', 'title': "Lei M'Ama"},
#  'TRMMAHU12903CB8069': {'artist': 'Joe Smooth', 'title': 'Back Home'},
#  'TRMMNOW128F42557E3': {'artist': 'Dinu Lipatti',
#   'title': '14 Valses/Waltzes (2005 Digital Remaster): No.6 in D flat Op.64 No.1'},
#  'TRMMNLJ128E07937A1': {'artist': 'Soundgarden', 'title': 'Gun'},
#  'TRMMNUB128F9316418': {'artist': 'Vaselines',
#   'title': 'Rosary Job (Demo) (Album)'},
#  'TRMMNGP128F42AF902': {'artist': 'Kingston Wall',
#   'title': 'When Something Old Dies'},
#  'TRMMNVU128EF343EED': {'artist': 'Masterboy', 'title': 'Feel The Heat 2000'},
#  'TRMMNTB128F427D710': {'artist': 'Sister Sledge',
#   'title': "Love Don't Go Through No Changes On Me"},
#  'TRMMNAZ128F932BA6C': {'artist': 'Fat Jon', 'title': 'You Are'},
#  'TRMMNAO128F42A0D24': {'artist': 'Miles Hunt', 'title': 'Falsified'},
#  'TRMMNUX128F1462B8D': {'artist': 'Bon Voyage',
#   'title': 'Third Marie_ The  (The Right Amount Album Version)'},
#  'TRMMNCE12903D0E4A3': {'artist': 'Patrick Saint-Eloi', 'title': 'Cheche'},
#  'TRMMNZS128EF34F916': {'artist': 'The Twinkle Brothers',
#   'title': 'Sodom & Gomorrah'},
#  'TRMMNZN128F42957D5': {'artist': 'Phantom Planet', 'title': 'Big Brat'},
#  'TRMMNEG128F426CC27': {'artist': 'The Monsters',
#   'title': 'The Love I Never Had\xa0'},
#  'TRMMNZV128F933A2D1': {'artist': 'Diego Torres',
#   'title': 'Alguien La Vió Partir'},
#  'TRMMNQX128F9323F75': {'artist': 'The Space Brothers', 'title': 'Forgiven'},
#  'TRMMNIO128F92D67C8': {'artist': 'La Rumeur',
#   'title': "Du Sommeil_ du Soleil_ de l'Oseille"},
#  'TRMMNEL128F4281683': {'artist': 'Mr. V',
#   'title': 'Put Your Drink Down [Original]'},
#  'TRMMNLX12903CC32E8': {'artist': 'Johnny Fiasco', 'title': 'Salsanova'},
#  'TRMMNRO12903CD3C8C': {'artist': 'Eric Chase',
#   'title': 'If You Tolerate This'},
#  'TRMMNDH12903CEC363': {'artist': 'Clann Zu',
#   'title': 'One Bedroom Apartment'},
#  'TRMMNBS128F422B2A5': {'artist': 'Panzer AG', 'title': 'tides that kill'},
#  'TRMMNEI128F92F92E8': {'artist': 'Nicole Willis',
#   'title': 'Didnt Feel No Pain'},
#  'TRMMNPQ12903CAFD18': {'artist': 'The Morning Benders', 'title': 'Cold War'},
#  'TRMMNMG128F9330934': {'artist': 'Go West',
#   'title': 'I Want To Hear It From You'},
#  'TRMMNSJ128F931E30C': {'artist': 'Mad Skillz',
#   'title': 'Unseen World [Explicit]'},
#  'TRMMNAK128F1482D23': {'artist': 'Endellion String Quartet',
#   'title': 'String Quartet No.12 in E flat major Op.127 : III Scherzo (Vivace)'},
#  'TRMMNYM128F42596AE': {'artist': 'Jacek Kaczmarski',
#   'title': 'Rehabilitacja Komunistów'},
#  'TRMMNYS128F4226E14': {'artist': 'Wealthy Beggar', 'title': 'Sucker 4U'},
#  'TRMMNIK128F9350CB6': {'artist': 'Winter Hours', 'title': 'Familiar Places'},
#  'TRMMNWR12903CAA849': {'artist': 'Texta',
#   'title': '(So schnö kaust gor net) schaun'},
#  'TRMMNPT128F428E2E8': {'artist': 'Shane MacGowan And The Popes',
#   'title': 'Come To The Bower'},
#  'TRMMNAV128F42303FA': {'artist': 'Duderstadt & Kirsty Hawkshaw',
#   'title': 'Beatitude'},
#  'TRMMNHC128F9316A4F': {'artist': 'Auditory Canvas',
#   'title': 'Mystery Trip (Original Mix)'},
#  'TRMMNBW128F4230214': {'artist': 'La Sonora Dinamita',
#   'title': 'El Viejo Del Sombreron'},
#  'TRMMNUO128F42374C2': {'artist': 'Larry The Cable Guy',
#   'title': 'The First Queer Santy Claus (Album Version)'},
#  'TRMMNFZ128F4251BB4': {'artist': 'Roy Brown', 'title': 'Big Town'},
#  'TRMMNCO128F4255DE0': {'artist': 'The Violet Burning', 'title': 'Blown Away'},
#  'TRMMNWF128F42889CB': {'artist': 'Billy Bragg',
#   'title': 'Sing Their Souls Back Home'},
#  'TRMMNCI128F9331E8E': {'artist': 'Richard Galliano', 'title': 'Mozambique'},
#  'TRMMNYS128F932A674': {'artist': 'Jimmy Nail',
#   'title': "Love Don't Live Here Anymore"},
# ...
#  'TRMMJCR128F932896A': {'artist': 'Romanowski',
#   'title': 'Dance Dance Dance (Tom Thump & Uplift Remix)'},
#  'TRMMJUZ128F9319340': {'artist': 'Furthest From the Star',
#   'title': 'So Many Goodbyes'},
#  'TRMMJWZ128F4256D38': {'artist': 'Martha And The Muffins',
#   'title': 'Sinking Land (2002 Digital Remaster)'},
#  'TRMMJKY128F935280A': {'artist': 'Pawtuckets', 'title': 'Lonely Dreams'},
#  'TRMMJLB128F149664D': {'artist': 'Righteous Brothers',
#   'title': 'Drown In My Own Tears'},
#  'TRMMJCI128F42471AA': {'artist': 'Timesbold', 'title': 'Sewn In Seams'},
#  'TRMMJSR128F9307702': {'artist': 'Indochine', 'title': 'Bye Bye Valentine'},
#  'TRMMJBB128F42576F7': {'artist': "Slim Cessna's Auto Club",
#   'title': 'Thorny Crown'},
#  'TRMMJFG128EF355EB1': {'artist': 'The Great Redneck Hope',
#   'title': 'Call Me Old-fashoined_ But I Think Trains Are Kick-ass.'},
#  'TRMMJNW128F92FFD2B': {'artist': 'Broadcast', 'title': 'Before We Begin'},
#  'TRMMJGN12903CCFB4B': {'artist': 'The-Dream',
#   'title': 'Love vs. Money: Part 2'},
#  'TRMMJKT12903CA4718': {'artist': 'Transilvanian Beat Club',
#   'title': 'Exzess Deluxe'},
#  'TRMMJPU128F92F336F': {'artist': 'Dead Prez',
#   'title': "Don't Forget Where U Goin'"},
#  'TRMMJZA128F42540C3': {'artist': 'Ricki-Lee',
#   'title': 'U Wanna Little Of This'},
#  'TRMMJMO12903CE88B5': {'artist': 'André van Duin',
#   'title': 'Een Echte Vriend (Ich War Noch Niemals In New York)'},
#  'TRMMJQR128F93421C6': {'artist': 'Stone Temple Pilots',
#   'title': 'A Song For Sleeping (LP Version)'},
#  'TRMMJWM12903CE5AEE': {'artist': 'Linda Hopkins',
#   'title': "I'm Going To Cry Right Out Of My Mind"},
#  'TRMMJCW128F92F6334': {'artist': 'La Lupita',
#   'title': 'Hay Que Pegarle A La Mujer'},
#  'TRMMJUW128F425E5E3': {'artist': 'Yvette Horner',
#   'title': 'Espana (Valse Espagnole)'},
#  'TRMMJXM128F4250CBA': {'artist': 'Eric B. & Rakim',
#   'title': "Set 'Em Straight"},
#  'TRMMJIO128F931DAE5': {'artist': 'Lushlife',
#   'title': 'Another Word For Paradise feat. Camp Lo'},
#  'TRMMJDS12903CE4CC7': {'artist': 'Mal', 'title': 'Se te ne vai'},
#  'TRMMJMA128F4289B2F': {'artist': 'Clay Aiken',
#   'title': "Don't Save It All For Christmas Day"},
#  'TRMMJGY128F92EF8C6': {'artist': 'Claude-Michel Schönberg',
#   'title': 'Pause Bonheur'},
#  'TRMMJZQ128F42941D9': {'artist': 'Thunderbirds Are Now!',
#   'title': 'Why We War'},
#  'TRMMJFC12903C95808': {'artist': 'Sir Harry Lauder',
#   'title': 'Will You Stop Your Tickling Jock'},
#  'TRMMJFH12903CBC710': {'artist': 'Jazz Liberatorz',
#   'title': 'Music makes the world go round (feat. Declaime)'},
#  'TRMMJHB128F42411E8': {'artist': 'Cat Power', 'title': 'Cross Bones Style'},
#  'TRMMJJS128F148A808': {'artist': 'Anita Lipnicka I John Porter',
#   'title': 'Chelsea Hotel #2'},
#  'TRMMJUY12903CEF1E5': {'artist': 'Été 67', 'title': "Tu n'es pas là"},
#  'TRMMSNV128F934A644': {'artist': 'Frankie Yankovic',
#   'title': "Let's Be Sentimental"},
#  'TRMMSMZ128EF3441A3': {'artist': 'Shawn McDonald', 'title': 'My Salvation'},
#  'TRMMSWR128F93263D5': {'artist': 'Lionel Richie', 'title': "Can't Slow Down"},
#  'TRMMSTU128F92EFFA0': {'artist': 'Raq', 'title': "Push Th' Little Daisies"},
#  'TRMMSUH128F9331B73': {'artist': 'Christopher',
#   'title': 'All I Have To Give'},
#  'TRMMSFU128F424FC05': {'artist': 'The Klezmatics', 'title': 'Bulgars #2'},
#  'TRMMSIX128F42883D7': {'artist': 'Phyllis Hyman',
#   'title': 'Under Your Spell'},
#  'TRMMSZF128F92EDC47': {'artist': 'Lions At Your Door', 'title': 'Layd'},
#  'TRMMSMW128F427ED0C': {'artist': 'Basia', 'title': 'I Was A Daughter'},
#  'TRMMSXG128F4260B30': {'artist': 'Blue Oyster Cult',
#   'title': "I'm On The Lamb But I Ain't No Sheep"},
#  'TRMMSWJ12903CB2CD3': {'artist': 'Jochen Miller', 'title': 'Red One'},
#  'TRMMSTR128F930BCEE': {'artist': 'Sibylle Baier', 'title': 'Give Me A Smile'},
#  'TRMMSLV12903CDA9F9': {'artist': 'Minipop', 'title': 'Wearing Thin'},
#  'TRMMSXZ128F14A58E3': {'artist': 'Art Garfunkel',
#   'title': "Let's Fall In Love (2007 Remastered LP Version)"},
#  'TRMMSNN128F934B9BE': {'artist': 'The Last', 'title': 'Every Summer Day'},
#  'TRMMSRQ128F92F29D2': {'artist': 'MC Paul Barman',
#   'title': 'Burping & Farting'},
#  'TRMMSVU128F425BCAA': {'artist': 'Drag The River', 'title': 'Medicine'},
#  'TRMMSQH128F42A8328': {'artist': 'Sweet', 'title': 'Done Me Wrong All Right'},
#  'TRMMSNP128F423CC5D': {'artist': 'Guardian',
#   'title': 'Queen Esther Mellow remix'},
#  'TRMMSRS128F1458D99': {'artist': 'Peter Hammill', 'title': 'Golden Promises'},
#  'TRMMSQC128F92F8FF3': {'artist': 'Ghost of the Russian Empire',
#   'title': 'The Winter Soldier'},
#  'TRMMSRC128F42A74FE': {'artist': 'Marcel',
#   'title': 'Ein grüner Frosch sitzt im Bikini'},
#  'TRMMSTZ128F92D226F': {'artist': 'Scorpions', 'title': 'Dark Lady'},
#  'TRMMSXV12903CC16FC': {'artist': 'Zion I', 'title': 'Do It Instrumental'},
#  'TRMMSKE128F9307AD9': {'artist': 'Olga Tañon',
#   'title': 'Desde Que Llegaste A Mi'},
#  'TRMMSHP12903CAF36F': {'artist': 'Eddie Kirkland', 'title': 'Georgia Woman'},
#  'TRMMSYD128F426B842': {'artist': 'Niño y pistola',
#   'title': 'This shit again'},
#  'TRMMSHL128F42933EB': {'artist': 'Clint Black',
#   'title': "You Don't Need Me Now"},
#  'TRMMSPH12903CB18A2': {'artist': 'KB', 'title': 'Rain Down'},
#  'TRMMSCF128F931145C': {'artist': 'John Fogerty', 'title': 'Blue Moon Nights'},
#  'TRMMSCF128F427100A': {'artist': 'Gold City',
#   'title': "It's Gonna Be A Good Day"},
#  'TRMMSSG128F92C6877': {'artist': 'ZZ Top', 'title': 'Sharp Dressed Man'},
#  'TRMMSCD128F424DE0D': {'artist': 'Dodgy', 'title': 'The Elephant'},
#  'TRMMSFT12903CE268C': {'artist': 'Marumari',
#   'title': 'Searching for the Sasha Wolf'},
#  'TRMMSVD12903CAE2DD': {'artist': 'Antonio Bribiesca', 'title': 'Amemonos'},
#  'TRMMSBH12903D0F3BF': {'artist': 'Brother ape',
#   'title': 'Cosmic Overdose (Redux)'},
#  'TRMMSJJ128F930290C': {'artist': 'Alexandroid', 'title': 'Edinorog'},
#  'TRMMSSO128F424C542': {'artist': 'Vince Guaraldi / Bola Sete',
#   'title': 'Mambossa'},
#  'TRMMSVZ128F92EC6CC': {'artist': 'Hopeton Lewis',
#   'title': 'How Great Thou Art'},
#  'TRMMSXG128F932D21C': {'artist': 'Heart', 'title': 'Perfect Goodbye'},
#  'TRMMSWW128F4272B31': {'artist': 'Elliot Goldenthal',
#   'title': 'The Dream Within'},
#  'TRMMSLJ128F42825B0': {'artist': 'DJ Krush',
#   'title': 'Decks-athron With Tatsuki'},
#  'TRMMSHG128E07934C8': {'artist': 'The Chameleons UK', 'title': 'Swamp Thing'},
#  'TRMMSDW128F92E9D29': {'artist': 'Charlie Walker',
#   'title': "Truck Drivin' man"},
#  'TRMMVIQ128F4268F0F': {'artist': 'Macabre', 'title': 'Ted Ted Bundy Song'},
#  'TRMMVPU128F145EC99': {'artist': 'Enrique Iglesias', 'title': 'Contigo'},
#  'TRMMVID128F42A62E7': {'artist': 'Frayser Boy',
#   'title': "I'm A Problem (Explcit Album Version)"},
#  'TRMMVDO128F9324CFA': {'artist': 'Brusco', 'title': 'Superstar'},
#  'TRMMVJK128F92D5331': {'artist': 'William Orbit',
#   'title': 'Escape To Mexico'},
#  'TRMMVMO128F4269124': {'artist': 'Paul Revere & The Raiders (featuring Mark Lindsay)',
#   'title': 'Hi-Heel Sneakers'},
#  'TRMMVER12903CB6662': {'artist': 'Andreas Dorau', 'title': 'Der Wasserfloh'},
#  'TRMMVID128F1495658': {'artist': 'Pink Floyd',
#   'title': 'Echoes (1992 Digital Remaster)'},
#  'TRMMVTY128F424C2C3': {'artist': 'MYSTIC PROPHECY', 'title': 'In hell'},
#  'TRMMVUG128E078A24A': {'artist': 'Daft Punk',
#   'title': 'Technologic (Vitalic Remix)'},
#  'TRMMVFL128F9307EC5': {'artist': 'IQ', 'title': 'Breathtaker'},
#  'TRMMVCI128F42ADEBC': {'artist': 'The Dead 60s',
#   'title': 'CNS Lazer Attack D-60'},
#  'TRMMVXN128F9330DE5': {'artist': 'Better Luck Next Time',
#   'title': 'Disaster Bound'},
#  'TRMMVKH128F4273F16': {'artist': 'Branford Marsalis Quartet',
#   'title': 'Doctone'},
#  'TRMMVBV128F931DA95': {'artist': 'Wild Billy Childish And The Musicians Of The British Empire',
#   'title': 'Joe Strummers Grave'},
#  'TRMMVYZ12903CAF12C': {'artist': 'Silkie', 'title': 'I Sed'},
#  'TRMMVPW128F4228722': {'artist': 'John Davis', 'title': 'Narrow'},
#  'TRMMVNA128F930CBAA': {'artist': 'Uli Jon Roth', 'title': 'Inquisition'},
#  'TRMMVNT128F425661E': {'artist': 'Maze Featuring Frankie Beverly',
#   'title': 'Joy And Pain (Live) (24-Bit Remastered 02) (2003 Digital Remaster) (Feat. Frankie Beverly)'},
#  'TRMMVBK128F1452BF5': {'artist': 'Bill Nelson',
#   'title': 'Do You Dream In Colour'},
#  'TRMMVIR128F92D6922': {'artist': 'The Enemy',
#   'title': 'Last Goodbye (Album Version)'},
#  'TRMMVON128F427E8BC': {'artist': 'Herman Dune',
#   'title': 'In The Summer Camp'},
#  'TRMMVGP128F92EEF56': {'artist': 'Los Indios Paraguayos', 'title': 'Ypane'},
#  'TRMMVQG128F931DD9E': {'artist': 'The Limp Twins', 'title': 'Elemental'},
#  'TRMMVCC128F9312BC7': {'artist': 'Tanya Morgan', 'title': 'Rowdy'},
#  'TRMMVEI128F42901E5': {'artist': 'L.S.G.',
#   'title': 'Blueprint (Single Version)'},
#  'TRMMVPH128F4274CEE': {'artist': 'The Challengers',
#   'title': 'Wipe Out (LP Version)'},
#  'TRMMVCV128F423F607': {'artist': 'Roseanna Vitro', 'title': 'Commitment'},
#  'TRMMVFA128F42690B1': {'artist': 'Tyrades', 'title': 'Same Sex Killers'},
#  'TRMMVRW128F1476BEE': {'artist': 'Ice Cube feat. WC',
#   'title': 'Chrome & Paint (Explicit) (feat. WC)'},
#  'TRMMVUS128F9303EEC': {'artist': 'Sonia Dersion', 'title': 'Jeannot'},
#  'TRMMVOP128F424793A': {'artist': 'The Pastels', 'title': "Thru' Your Heart"},
#  'TRMMVYI128F92E2DA4': {'artist': 'Candy Dulfer', 'title': '2 Miles'},
#  'TRMMVEB128F92F18E6': {'artist': 'Soldier Dolls', 'title': 'Headpains'},
#  'TRMMVQT128F42810B3': {'artist': '67 Special', 'title': 'Quickdraw'},
#  'TRMMVAX128F9360E3D': {'artist': 'Pat Travers', 'title': 'Elijah'},
#  'TRMMVJZ128F425C929': {'artist': 'Luther Allison', 'title': 'K.T.'},
#  'TRMMVEG128F92DF81C': {'artist': 'Brian Wilson',
#   'title': 'Morning Beat (Live at the AOL Studios)'},
#  'TRMMVOA128F9321EE0': {'artist': 'Hank Williams', 'title': 'Rootie Tootie'},
#  'TRMMVCF128F92E32AF': {'artist': 'Frida', 'title': 'Varför gräva ner sig'},
#  'TRMMVPU128F14583F3': {'artist': 'Ambitious Lovers', 'title': 'Steel Wool'},
#  'TRMMVNH128E078290D': {'artist': 'The Special AKA', 'title': 'Racist Friend'},
#  'TRMMVQN128F4279167': {'artist': 'Gerard Lenorman', 'title': 'Sur Les Quais'},
#  'TRMMVNT128E0783FC6': {'artist': 'JoJo', 'title': "Baby It's You"},
#  'TRMMVGH128F423CB90': {'artist': 'Tanto Metro & Devonte',
#   'title': 'Got News For You'},
#  'TRMMVRR128F426F771': {'artist': 'Michael Nyman',
#   'title': 'Part 1 (Concerto For Harpsichord And Strings_ Move'},
#  'TRMMVKD128F4255C92': {'artist': 'Charlie Peacock',
#   'title': 'Lady Soul (Aretha In The A.M.)'},
#  'TRMMVVQ128F1453BED': {'artist': 'C-Murder', 'title': 'Akickdoe!'},
#  'TRMMVNV12903CBF0B0': {'artist': 'Bain Wolfkind',
#   'title': 'The Eye of the Hurricane'},
#  'TRMMDGR128F426DE4F': {'artist': 'Slum Village', 'title': 'Fantastic 4'},
#  'TRMMDNE128F427C091': {'artist': 'Whiskeytown', 'title': 'Indian Gown'},
#  'TRMMDHL128F4276157': {'artist': 'Schweisser', 'title': 'Scheisskind'},
#  'TRMMDAS128F4234EBF': {'artist': 'Smokey Wilson',
#   'title': "Smokey's Shuffle (Instrumental)"},
#  'TRMMDYX128F934EB76': {'artist': 'Ken Navarro', 'title': 'Wake up call'},
#  'TRMMDLW128F1471733': {'artist': 'Status Quo', 'title': 'In The Army Now'},
#  'TRMMDJM128F4285E8C': {'artist': 'Syrian',
#   'title': 'Enforcer (Nimm das! Remix by NamNamBulu)'},
#  'TRMMDKN12903CB2F68': {'artist': 'Impuls', 'title': 'Igjennom Alt'},
#  'TRMMDSX128F93195E8': {'artist': 'Acoustic Strawbs', 'title': 'Evergreen'},
#  'TRMMDIO128F4234BC4': {'artist': 'Matt Nathanson',
#   'title': 'Everything You Say Sounds Like Gospel'},
#  'TRMMDXZ128F42A29E0': {'artist': 'Ali & Gipp / Big Rube', 'title': 'Intro'},
#  'TRMMDFU128F426CBDF': {'artist': 'Reverend Beat-Man & The Un-Believers',
#   'title': "You Don't Know"},
#  'TRMMDFO128F1473E53': {'artist': 'Hombres G',
#   'title': 'Voy A Pasarmelo Bien'},
#  'TRMMDUA128F42A1F34': {'artist': 'Stan Ridgway',
#   'title': "Can't Stop The Show (Live)"},
#  'TRMMDBJ128F14A542C': {'artist': 'JoAnn Campbell',
#   'title': 'I Really Really Love You (LP Version)'},
#  'TRMMDBT128F4265989': {'artist': 'Dan Siegel', 'title': 'Next To You'},
#  'TRMMDFZ128F92D8782': {'artist': 'McEnroe',
#   'title': 'Midlife Crisis (Early Though)'},
#  'TRMMDMR128F92C2812': {'artist': 'Céline Dion', 'title': 'A cause'},
#  'TRMMDQF128F92E74D0': {'artist': 'Reckless Kelly',
#   'title': 'Break My Heart Tonight'},
#  'TRMMDCP12903CC596D': {'artist': 'Mindless Faith', 'title': 'The Unseen'},
#  'TRMMDTR128F92FB36A': {'artist': 'The Muses Rapt',
#   'title': 'Spiritual Healing'},
#  'TRMMDER128F92F40E6': {'artist': 'Paul Rogers', 'title': "I'll Be Creepin'"},
#  'TRMMDGP128F92C4EEF': {'artist': 'Motorcitysoul', 'title': 'Mango'},
#  'TRMMDKH12903CE9EA3': {'artist': 'The Byrds', 'title': 'Carry On'},
#  'TRMMDVB12903CE2FF6': {'artist': 'Craig Morgan',
#   'title': 'Redneck Yacht Club'},
#  'TRMMDNX128F42A726C': {'artist': 'Robert Natus', 'title': 'Getting Time'},
#  'TRMMDDX12903CE3D19': {'artist': 'Vieja Trova Santiaguera',
#   'title': 'La guinda'},
#  'TRMMDJD128F93450F5': {'artist': 'Mauro Pagani', 'title': 'Il litigio'},
#  'TRMMDDL12903CB25BF': {'artist': 'Steve Bug', 'title': 'Cherry Blossoms'},
#  'TRMMDIK12903D0EA83': {'artist': 'Kultiration', 'title': 'Krigare'},
#  'TRMMDXB128E078A256': {'artist': 'Gyllene Tider',
#   'title': 'En Sten Vid En Sjö I En Skog'},
#  'TRMMDVC128EF3515A0': {'artist': 'Marcia Griffiths', 'title': 'Survival'},
#  'TRMMDKM128F9327E4C': {'artist': 'Minor Majority',
#   'title': 'Either Way I Think You Know'},
#  'TRMMDSG128F4288CD9': {'artist': 'R.L. Burnside & The Sound Machine',
#   'title': 'Searching For My Baby'},
#  'TRMMDVL128F92FD194': {'artist': 'Duke Ellington Orchestra',
#   'title': 'Blue Skies'},
#  'TRMMDKJ128F4293E9F': {'artist': 'Rascal Flatts',
#   'title': 'The Day Before You'},
#  'TRMMDDA12903CB2D2C': {'artist': 'Pascal Parisot', 'title': 'Les filles'},
#  'TRMMDPZ128F422344B': {'artist': 'Sex Pistols',
#   'title': 'Einmal War Belsen Wirflich Bortrefflich (1993 Digital Remaster)'},
#  'TRMMDSU12903CC030E': {'artist': 'Metallic Falcons', 'title': 'Berry Metal'},
#  'TRMMDBG128F9335B9D': {'artist': "Sinéad O'Connor",
#   'title': 'Silent Night (Long Version) (2009 Digital Remaster)'},
#  'TRMMDYQ128F4275360': {'artist': 'Kid Loco', 'title': 'Motorcycle Angels'},
#  'TRMMDSS128F93359AD': {'artist': 'Ike And Tina Turner',
#   'title': 'Son Of A Preacher Man'},
#  'TRMMOBE12903CEB626': {'artist': '& And Oceans',
#   'title': 'Halcyon: The Heavy Silence: In Silent Rain'},
#  'TRMMORK12903D052FA': {'artist': 'Diego Martin',
#   'title': 'Haces llover (con Malu)'},
#  'TRMMOJC128F423F8C7': {'artist': 'The Orioles', 'title': 'Once In A While'},
#  'TRMMOBS12903CCB7AF': {'artist': "Fun Lovin' Criminals",
#   'title': 'Mi Corazon'},
#  'TRMMOXD128F92E1A1F': {'artist': 'Moneybrother',
#   'title': 'It Is Time For Falling Apart'},
#  'TRMMOJN128F930B7B9': {'artist': 'Eko Fresh feat. G-Style',
#   'title': 'Ek is back'},
#  'TRMMOJB12903CD1671': {'artist': 'Play-N-Skillz',
#   'title': 'TX 2 NY  (feat. Blackchild)'},
#  'TRMMOWC128F428336E': {'artist': 'Meg & Dia',
#   'title': 'Monster (Album Version)'},
#  'TRMMOPW128F4280839': {'artist': 'Bo Carter', 'title': 'Bo Carter Special'},
#  'TRMMOLD128F9318C2D': {'artist': 'The Sensational Alex Harvey Band',
#   'title': 'Vambo'},
#  'TRMMOSQ128F146118B': {'artist': 'Peter Sarstedt', 'title': 'Blagged'},
#  'TRMMOAN128F93427DB': {'artist': 'The Click Five',
#   'title': 'Long Way To Go [Acoustic Version]'},
#  'TRMMOFM128F93036CC': {'artist': 'Howard Hewett', 'title': 'If Only'},
#  'TRMMOJV128F92FAC64': {'artist': 'Lee Ann Womack',
#   'title': 'Stubborn (Psalms 151)'},
#  'TRMMOSR128F42875F7': {'artist': 'Federico Franchi',
#   'title': 'Cream (Robbie Rivera\x19s Juicy Ibiza Mix)'},
#  'TRMMOHX12903CFFD06': {'artist': 'Dubioza kolektiv',
#   'title': 'Cannot Forgive'},
#  'TRMMOTD128F930FEDE': {'artist': 'The Waybacks',
#   'title': 'Last Steam Engine Train'},
#  'TRMMOYO128F932ED42': {'artist': 'TYR', 'title': 'Hipokrisia: Hipokrisia'},
#  'TRMMOLL12903CD06CD': {'artist': 'The Glass', 'title': 'Four Four Letter'},
#  'TRMMOPB12903CE32C3': {'artist': 'Giano', 'title': 'Good Times'},
#  'TRMMOVM128F92EBFBF': {'artist': 'Efdemin', 'title': 'Further Back'},
#  'TRMMOCH128F92E3318': {'artist': 'Arkona', 'title': 'Tuman Yarom'},
#  ...}

# %% [markdown]
# ### Creating a DataFrame for the 2 Files and Merging Them

# %% [markdown]
# #### DataFrame 1

# %%
dframe = {
    'TRACKID': list(all_songs_dict.keys()),
    'Text': [all_songs_dict[x] for x in all_songs_dict.keys()]
    }
msdid_df = pd.DataFrame.from_dict(dframe)
print(msdid_df.shape)
msdid_df.head()
# Out:
# (210519, 2)
#               TRACKID                                               Text
# 0  TRAAAAV128F421A322  like like de got would seem someon understand ...
# 1  TRAAABD128F429CF47  know know know know know time time time la la ...
# 2  TRAAAED128E0783FAB  love love love love love love love love love l...
# 3  TRAAAEF128F4273421  know got got got feel let would would would ey...
# 4  TRAAAEW128F42930C0  like take would wo someth stay burn burn burn ...

# %% [markdown]
# #### DataFrame 2

# %%
dframe2 = {
    'TRACKID': msdid_df['TRACKID'],
    'artist': [all_song_meta_dict[x]['artist'] for x in msdid_df['TRACKID']],
    'title': [all_song_meta_dict[x]['title'] for x in msdid_df['TRACKID']]
    }
meta_df = pd.DataFrame.from_dict(dframe2)
print(meta_df.shape)
meta_df.head()
# Out:
# (210519, 3)
#               TRACKID             artist                             title
# 0  TRAAAAV128F421A322  Western Addiction  A Poor Recipe For Civic Cohesion
# 1  TRAAABD128F429CF47       The Box Tops                         Soul Deep
# 2  TRAAAED128E0783FAB       Jamie Cullum                   It's About Time
# 3  TRAAAEF128F4273421           Adam Ant                   Something Girls
# 4  TRAAAEW128F42930C0    Broken Spindles      Burn My Body (Album Version)

# %% [markdown]
# #### Merging

# %%
final_df = pd.merge(msdid_df, meta_df, on='TRACKID', how='left')

# %%
final_df.head()
# Out:
#               TRACKID                                               Text  \
# 0  TRAAAAV128F421A322  like like de got would seem someon understand ...
# 1  TRAAABD128F429CF47  know know know know know time time time la la ...
# 2  TRAAAED128E0783FAB  love love love love love love love love love l...
# 3  TRAAAEF128F4273421  know got got got feel let would would would ey...
# 4  TRAAAEW128F42930C0  like take would wo someth stay burn burn burn ...
#
#               artist                             title
# 0  Western Addiction  A Poor Recipe For Civic Cohesion
# 1       The Box Tops                         Soul Deep
# 2       Jamie Cullum                   It's About Time
# 3           Adam Ant                   Something Girls
# 4    Broken Spindles      Burn My Body (Album Version)

# %% [markdown]
# ## Model Training and Generating Word Embeddings

# %%
# Get Training Data
data = final_df['Text'].tolist()

# %%
from gensim.models.doc2vec import Doc2Vec, TaggedDocument

# %%
train_corpus = [TaggedDocument(words=word_tokenize(_d.lower()), tags=[str(i)]) for i, _d in list(enumerate(data))]

# %%
#Building Model
model = Doc2Vec(vector_size=50, min_count=1, epochs=10, dm=0)
model.build_vocab(train_corpus)

# %%
#Training Model
model.train(train_corpus, total_examples=model.corpus_count, epochs=model.epochs)

# %%
model.save('trained_model_example')

# %%
model = Doc2Vec.load('trained_model_example')

# %%
emb_df = pd.DataFrame([model.docvecs[f'{i}'] for i in range(len(final_df))])
fe_df = final_df.copy()
for c in emb_df.columns:
    fe_df[c] = emb_df[c]

# %%
fe_df.info
# Out:
# <bound method DataFrame.info of                    TRACKID                                               Text  \
# 0       TRAAAAV128F421A322  like like de got would seem someon understand ...
# 1       TRAAABD128F429CF47  know know know know know time time time la la ...
# 2       TRAAAED128E0783FAB  love love love love love love love love love l...
# 3       TRAAAEF128F4273421  know got got got feel let would would would ey...
# 4       TRAAAEW128F42930C0  like take would wo someth stay burn burn burn ...
# ...                    ...                                                ...
# 210514  TRZZZWS128F429CF87  que que que que que que que de en te te te te ...
# 210515  TRZZZXA128F428ED56  time la get eye think give dream wo wo head so...
# 210516  TRZZZXV128F4289747  know like like like time get get get never bac...
# 210517  TRZZZYV128F92E996D  get get get get get get get get get get get ge...
# 210518  TRZZZYX128F92D32C6  know know time time time go go go go go go go ...
#
#                    artist                                title         0  \
# 0       Western Addiction     A Poor Recipe For Civic Cohesion  0.137623
# 1            The Box Tops                            Soul Deep  0.082029
# 2            Jamie Cullum                      It's About Time  0.031915
# 3                Adam Ant                      Something Girls -0.249924
# 4         Broken Spindles         Burn My Body (Album Version) -0.317553
# ...                   ...                                  ...       ...
# 210514    Los Prisioneros             Que No Destrocen Tu Vida  0.016093
# 210515     The God Awfuls                            No Angels -0.358129
# 210516          BlackHawk                      Stepping Stones -0.450735
# 210517                TLC                             Dear Lie -0.003024
# 210518       Donald Fagen  Trans-Island Skyway (Album Version) -0.366646
#
#                1         2         3         4         5  ...        40  \
# 0      -0.117216 -0.280224  0.083149 -0.321080  0.107093  ...  0.035835
# 1      -0.053658  0.084980 -0.310631 -0.097508 -0.177447  ...  0.083086
# 2       0.246888 -0.151413  0.079780 -0.010440 -0.092772  ... -0.258726
# 3       0.309107 -0.052767  0.296513 -0.082594 -0.534469  ...  0.357091
# 4       0.190749  0.001964  0.201047 -0.322117 -0.166265  ... -0.150398
# ...          ...       ...       ...       ...       ...  ...       ...
# 210514  0.307799  0.131260  0.096767 -0.213210 -0.108611  ...  0.202943
# 210515 -0.156286 -0.223034  0.387327  0.107640 -0.211537  ...  0.112586
# 210516  0.050667 -0.732170 -0.110897  0.010947 -0.513352  ... -0.269106
# 210517 -0.061988  0.059133  0.304983  0.224039  0.021038  ... -0.580548
# 210518  0.097116 -0.065501  0.287392 -0.152889 -0.228835  ... -0.075487
#
#               41        42        43        44        45        46        47  \
# 0       0.066258 -0.071603  0.082365 -0.439432 -0.472480  0.217788 -0.008332
# 1      -0.320418  0.001067 -0.147280 -0.405358  0.049638  0.313096 -0.094380
# 2       0.290960 -0.368958 -0.057273 -0.652711  0.465756  0.766044  0.407142
# 3      -0.262231  0.230872 -0.242239 -0.538470  0.093852  0.189016  0.027075
# 4      -0.089602  0.048922 -0.002626  0.038423 -0.153119  0.298262  0.189580
# ...          ...       ...       ...       ...       ...       ...       ...
# 210514  0.035086 -0.235105 -0.022869 -0.202482 -0.437658  0.199242 -0.701366
# 210515  0.041164 -0.029369  0.136669 -0.175467 -0.143211 -0.253457  0.459102
# 210516  0.042075 -0.308154  0.313061  0.184735 -0.043792  0.533157  0.054126
# 210517 -0.297967 -0.257258 -0.624466  0.427120  0.111206  0.407148  0.075770
# 210518 -0.074911 -0.042314  0.366952  0.052484  0.093136 -0.114299 -0.005406
#
#               48        49
# 0      -0.026047 -0.102714
# 1       0.070110  0.154268
# 2      -0.534267  0.313268
# 3      -0.345188  0.292881
# 4       0.271752 -0.170289
# ...          ...       ...
# 210514  0.027847 -0.186267
# 210515  0.230313  0.302527
# 210516  0.110097  0.480503
# 210517  0.212001  0.292479
# 210518  0.362664  0.143672
#
# [210519 rows x 54 columns]>

# %%
fe_df.to_csv('Doc2VecEmbeddings.csv', index=False)

# %% [markdown]
# # WORD2VEC

# %%
word_lists
# Out:
# [['i', 'i', 'i', 'i'],
#  ['the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the'],
#  ['to', 'to', 'to'],
#  ['and', 'and', 'and', 'and', 'and', 'and'],
#  ['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'],
#  ['me'],
#  ['it', 'it', 'it', 'it', 'it'],
#  ['not'],
#  ['in', 'in', 'in', 'in', 'in', 'in', 'in', 'in', 'in', 'in', 'in', 'in'],
#  ['my', 'my'],
#  ['is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is'],
#  ['of', 'of', 'of', 'of', 'of'],
#  ['that', 'that', 'that', 'that'],
#  ['on', 'on'],
#  ['are', 'are', 'are', 'are'],
#  ['we', 'we', 'we', 'we'],
#  ['will', 'will'],
#  ['all', 'all', 'all'],
#  ['be', 'be', 'be'],
#  ['know', 'know'],
#  ['this', 'this', 'this'],
#  ['with', 'with', 'with', 'with', 'with'],
#  ['just', 'just', 'just'],
#  ['when', 'when'],
#  ['now', 'now'],
#  ['time', 'time', 'time'],
#  ['there', 'there'],
#  ['go', 'go', 'go', 'go', 'go', 'go', 'go'],
#  ['up', 'up'],
#  ['they', 'they'],
#  ['out', 'out'],
#  ['get', 'get', 'get', 'get', 'get', 'get', 'get', 'get'],
#  ['was', 'was'],
#  ['if'],
#  ['from'],
#  ['let', 'let', 'let', 'let', 'let', 'let', 'let', 'let', 'let', 'let'],
#  ['make'],
#  ['say'],
#  ['day', 'day'],
#  ['at'],
#  ['back'],
#  ['by'],
#  ['could', 'could'],
#  ['eye'],
#  ['thing', 'thing'],
#  ['caus'],
#  ['gonna'],
#  ['who'],
#  ['too'],
#  ['or'],
#  ['long'],
#  ['good', 'good', 'good', 'good'],
#  ['about', 'about'],
#  ['some', 'some', 'some'],
#  ['over'],
#  ['littl', 'littl'],
#  ['hand'],
#  ['everi', 'everi'],
#  ['into'],
#  ['wait'],
#  ['these'],
#  ['sun'],
#  ['off'],
#  ['chorus', 'chorus', 'chorus'],
#  ['put'],
#  ['talk', 'talk'],
#  ['use'],
#  ['those'],
#  ['sweet'],
#  ['breath'],
#  ['year', 'year'],
#  ['side'],
#  ['blood'],
#  ['sound'],
#  ['ride'],
#  ['street'],
#  ['beauti'],
#  ['roll'],
#  ['deep'],
#  ['set'],
#  ['broken'],
#  ['road'],
#  ['blind'],
#  ['reach'],
#  ['past'],
#  ['final'],
#  ['born'],
#  ['laugh'],
#  ['drive', 'drive', 'drive'],
#  ['pull'],
#  ['lot'],
#  ['kid', 'kid'],
#  ['clear'],
#  ['fast'],
#  ['troubl', 'troubl'],
#  ['somewher'],
#  ['cool'],
#  ['tight'],
#  ['father'],
#  ['kick'],
#  ['dawn'],
#  ['daddi', 'daddi', 'daddi', 'daddi', 'daddi', 'daddi', 'daddi'],
#  ['minut'],
#  ['lock'],
#  ['yesterday'],
#  ['glass'],
#  ['key'],
#  ['wheel'],
#  ['five'],
#  ['tryin'],
#  ['brought'],
#  ['cmon', 'cmon', 'cmon', 'cmon', 'cmon', 'cmon', 'cmon', 'cmon', 'cmon'],
#  ['below'],
#  ['leg'],
#  ['harder'],
#  ['sigh'],
#  ['noon'],
#  ['total'],
#  ['bullet'],
#  ['cryin'],
#  ['fresh', 'fresh'],
#  ['frame'],
#  ['monster'],
#  ['screen'],
#  ['wreck'],
#  ['heel'],
#  ['lane'],
#  ['10'],
#  ['relax'],
#  ['grind'],
#  ['zone'],
#  ['samba'],
#  ['bubbl'],
#  ['dancer'],
#  ['boil'],
#  ['plate'],
#  ['bug'],
#  ['farm'],
#  ['rout', 'rout'],
#  ['strap'],
#  ['lawn'],
#  ['program'],
#  ['zoo'],
#  ['freeway']]

# %%
from gensim.test.utils import common_texts, get_tmpfile
from gensim.models import Word2Vec

# %%
model2 = Word2Vec(word_lists, min_count=1,size= 50,workers=3, window =3, sg = 1)

# %%
model2['freeway']
# Out:
# <ipython-input-78-dae5f089cc76>:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   model2['freeway']
# array([ 3.3840095e-03, -4.4054864e-03, -9.7944094e-03, -4.3173591e-03,
#         1.5595024e-03,  7.4093193e-03,  7.3416973e-03,  6.5208215e-04,
#         3.0503003e-03, -6.3301501e-04,  5.6095273e-06,  5.2574901e-03,
#        -4.0683565e-03,  7.4931015e-03,  4.7563161e-03, -3.5820177e-03,
#        -5.8123134e-03,  1.9687598e-03, -8.4946677e-03,  7.4363686e-03,
#         4.9292510e-03,  2.4051864e-03, -5.3005372e-03, -8.9102164e-03,
#         3.0138027e-03, -6.7384058e-04, -8.8066002e-03, -9.8001892e-03,
#        -7.6274467e-03, -8.3928797e-03,  8.1424210e-03, -8.2012797e-03,
#        -6.7775925e-03,  3.8658418e-03, -2.6700406e-03, -7.6875216e-03,
#        -3.9550965e-03,  2.8430081e-03,  9.2689022e-03,  4.8152180e-03,
#        -2.3634830e-03,  5.6392835e-03,  5.0677639e-04,  6.7160401e-04,
#         1.9137472e-03, -9.8744798e-03, -8.1901914e-03, -2.5042188e-03,
#         6.1770319e-03,  1.3296956e-03], dtype=float32)

# %%
model2['zoo']
# Out:
# <ipython-input-79-a8f79b73fad4>:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   model2['zoo']
# array([ 8.5522974e-04, -6.3166735e-03, -6.9513051e-03,  3.7799885e-03,
#        -1.5991951e-03,  5.5573643e-03,  5.9341979e-03,  7.6739127e-03,
#         9.4716800e-03, -8.3372677e-03, -3.6957236e-03,  6.0644546e-03,
#         3.2513705e-03, -4.2479937e-03,  3.7034019e-03,  9.7203068e-03,
#         6.1284322e-03,  8.8971499e-03,  6.3078855e-03,  2.0149725e-03,
#         6.9063758e-03,  8.4457465e-04, -9.2334524e-03, -1.0857463e-03,
#        -4.7662919e-03,  3.8335992e-03, -7.7826860e-03,  9.4485823e-03,
#         3.5316560e-03,  5.7974518e-03, -7.2429758e-03, -2.4594979e-03,
#         2.1971539e-03, -4.8305192e-03, -4.5652422e-03, -6.9431369e-03,
#        -1.1417641e-03,  1.1282571e-04, -1.1685616e-05,  5.6417966e-03,
#        -7.4185836e-03, -5.3891032e-03, -6.5380158e-03, -5.7706367e-03,
#        -3.2658593e-04, -7.5059324e-03, -8.9857308e-03, -9.1335941e-03,
#         5.7804799e-03,  5.5380967e-03], dtype=float32)
